# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
file_path = r"C:\Users\Braydon\Desktop\Shein_Data\Pivot_Data\Shein\Shein_Cleaned.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                              Cloth_Desc  Price
# 0                SHEIN Unity Solid Form Fitted Bodysuit   8.35
# 1             Cherry Embroidery Lantern Sleeve Cardigan  19.00
# 2     Random Allover Floral Print Ruched Bust Ruffle...  17.00
# 3            SHEIN SXY Cut Out Waist Tube Bodycon Dress   9.00
# 4              Solid Drawstring Slant Pocket Sweatpants  13.40
# ...                                                 ...    ...
# 4789  Joyfunear Sequin Bodice Backless Mesh Cami For...  26.00
# 4790                     Rainbow And Slogan Graphic Tee   8.00
# 4791                        2pack Chiffon Knot Cover Up   7.49
# 4792  SHEIN BAE Solid Criss Cross Tie Backless Split...  12.00
# 4793  SHEIN BAE Lace up Backless Split Hem Sequince ...  15.40
#
# [4794 rows x 2 columns]

# %%
cloth_word_lst = []

for item in df['Cloth_Desc']:
    item = item.split()
    for thing in item:
        cloth_word_lst.append(thing)

# %%
cloth_word_count = Counter(cloth_word_lst)

# %%
cloth_word_count
# Out:
# Counter({'SHEIN': 1812,
#          'Unity': 202,
#          'Solid': 806,
#          'Form': 25,
#          'Fitted': 67,
#          'Bodysuit': 94,
#          'Cherry': 4,
#          'Embroidery': 58,
#          'Lantern': 115,
#          'Sleeve': 668,
#          'Cardigan': 59,
#          'Random': 37,
#          'Allover': 176,
#          'Floral': 490,
#          'Print': 845,
#          'Ruched': 259,
#          'Bust': 38,
#          'Ruffle': 285,
#          'Hem': 567,
#          'Cami': 419,
#          'Dress': 1385,
#          'SXY': 351,
#          'Cut': 242,
#          'Out': 203,
#          'Waist': 283,
#          'Tube': 153,
#          'Bodycon': 263,
#          'Drawstring': 182,
#          'Slant': 51,
#          'Pocket': 179,
#          'Sweatpants': 65,
#          'Ring': 46,
#          'Linked': 49,
#          'Triangle': 125,
#          'Thong': 30,
#          'Bikini': 444,
#          'Swimsuit': 403,
#          'Leather': 41,
#          'Look': 6,
#          'Zipper': 50,
#          'Fly': 24,
#          'Flare': 63,
#          'Leg': 185,
#          'Jeans': 157,
#          '3pack': 21,
#          'Tropical': 64,
#          'Halter': 263,
#          'Side': 180,
#          'O-ring': 18,
#          'Detail': 145,
#          'Textured': 68,
#          'Letter': 175,
#          'Graphic': 219,
#          'Drop': 419,
#          'Shoulder': 638,
#          'Thermal': 109,
#          'Pullover': 29,
#          'Ribbed': 145,
#          'Crop': 547,
#          'Tank': 228,
#          'Top': 775,
#          'Pencil': 12,
#          'Ditsy': 137,
#          'Stacked': 2,
#          'Skinny': 34,
#          'Scoop': 74,
#          'Neck': 772,
#          'Unitard': 55,
#          'Jumpsuit': 90,
#          'Contrast': 133,
#          'Binding': 30,
#          'ICON': 138,
#          'Tie': 441,
#          'Backless': 239,
#          'Plain': 60,
#          'Micro': 30,
#          'Heart': 63,
#          'Pattern': 85,
#          'Sweater': 253,
#          'Lace': 175,
#          'Trim': 284,
#          'Hook': 9,
#          '&': 420,
#          'Eye': 9,
#          'Split': 251,
#          'Modely': 24,
#          'Houndstooth': 16,
#          'Pads': 6,
#          'Mock': 136,
#          'Shirred': 100,
#          'Bodice': 14,
#          'Without': 119,
#          'Belt': 31,
#          'Flap': 74,
#          'Cargo': 40,
#          'Flounce': 118,
#          'Blouse': 249,
#          'Knot': 169,
#          'Kimono': 24,
#          'EMERY': 242,
#          'ROSE': 242,
#          'Crisscross': 53,
#          'Wide': 90,
#          'Keyhole': 40,
#          'Back': 247,
#          'Colorblock': 75,
#          'Collar': 81,
#          'Bell': 11,
#          'Front': 424,
#          'Crochet': 15,
#          'Two': 38,
#          'Tone': 38,
#          'Notch': 14,
#          'Rib-knit': 76,
#          'Knit': 244,
#          'Duster': 14,
#          'Color': 61,
#          'Block': 63,
#          'Lapel': 30,
#          'Single': 32,
#          'Breasted': 24,
#          'Blazer': 88,
#          'BASICS': 63,
#          'Up': 253,
#          'Hooded': 25,
#          'Sweatshirt': 86,
#          'DAZY': 127,
#          'Button': 177,
#          'Shirt': 86,
#          'PU': 43,
#          'EZwear': 304,
#          '3pcs': 14,
#          'Romper': 53,
#          'MOD': 78,
#          'Twist': 123,
#          'Strap': 18,
#          'Rib': 68,
#          'Star': 15,
#          'Distressed': 3,
#          'Underwire': 27,
#          '4pcs': 12,
#          'Off': 48,
#          'Cut-out': 24,
#          'Flutter': 8,
#          'Belted': 143,
#          'Puff': 85,
#          'Double': 31,
#          'Pants': 199,
#          'Car': 11,
#          'Tee': 499,
#          'Sleeveless': 27,
#          'Zip': 141,
#          'Vest': 32,
#          'Puffer': 29,
#          'Coat': 43,
#          'One': 125,
#          'ROMWE': 42,
#          'Slogan': 62,
#          'Cartoon': 23,
#          'Oversized': 32,
#          'V': 61,
#          'Sheer': 36,
#          'Asymmetrical': 103,
#          'Grid': 4,
#          'Notched': 90,
#          'Neckline': 22,
#          'High': 275,
#          'Thigh': 165,
#          'Skirt': 184,
#          'Striped': 118,
#          'Pointelle': 16,
#          'BAE': 148,
#          'Square': 61,
#          'Fluid': 5,
#          'Smocked': 35,
#          'Cover': 87,
#          'Funnel': 2,
#          'Winter': 3,
#          'Guipure': 42,
#          'Panel': 39,
#          'Ripped': 73,
#          'Raw': 51,
#          'Denim': 51,
#          'Shorts': 144,
#          'Boat': 18,
#          'Tall': 37,
#          'A-line': 48,
#          'Bishop': 39,
#          'Wrap': 107,
#          'Leopard': 44,
#          'Frill': 69,
#          'Bleach': 6,
#          'Wash': 8,
#          'Patch': 4,
#          'BIZwear': 27,
#          'Waisted': 32,
#          'Criss': 29,
#          'Cross': 42,
#          'VCAY': 180,
#          'Draped': 28,
#          'Open': 66,
#          'Dalmatian': 14,
#          'Layered': 37,
#          'Butterfly': 71,
#          'Plaid': 54,
#          'Shawl': 36,
#          'Glitter': 18,
#          '90s': 14,
#          'Super': 15,
#          'Hoodie': 79,
#          'Bandeau': 30,
#          'Hidden': 5,
#          'Fold': 10,
#          'Pleated': 45,
#          'Pinafore': 2,
#          'Lace-up': 5,
#          'Hanky': 22,
#          'Stripe': 15,
#          'PETITE': 112,
#          'Seam': 10,
#          'Gold': 1,
#          'Argyle': 3,
#          'Batwing': 120,
#          'Satin': 74,
#          'Feather': 7,
#          'X': 34,
#          'Aurora': 2,
#          'Celli': 2,
#          'Straight': 53,
#          'Leggings': 32,
#          'Lined': 80,
#          'Dobby': 8,
#          'Mesh': 127,
#          'Raglan': 39,
#          'Bustier': 20,
#          'Patched': 32,
#          'Overall': 19,
#          'Thumb': 3,
#          'Holes': 3,
#          'Jacket': 39,
#          'Dual': 19,
#          'V-neck': 14,
#          'Piece': 27,
#          'Elastic': 28,
#          'Swiss': 35,
#          'Dot': 72,
#          'Slit': 50,
#          '2pcs': 6,
#          'Fringe': 34,
#          'Push': 13,
#          'Tankini': 3,
#          'Bottom': 6,
#          'All': 6,
#          'Over': 6,
#          'Geo': 27,
#          'Bikinx': 30,
#          'Whip': 5,
#          'Stitch': 10,
#          'Glen': 3,
#          'Ankle': 2,
#          'Overcoat': 4,
#          'Eyelet': 17,
#          'U-ring': 2,
#          'Overlap': 14,
#          'Insert': 30,
#          'Dye': 42,
#          'Set': 45,
#          'Pockets': 15,
#          'Sweetheart': 35,
#          'Hollow': 26,
#          'Scallop': 10,
#          'Tunic': 34,
#          'Suit': 11,
#          'Paisley': 24,
#          'Trench': 2,
#          'Lettuce': 44,
#          'Polka': 37,
#          'Petal': 10,
#          'Frenchy': 58,
#          'Track': 13,
#          'Panty': 13,
#          'Tape': 10,
#          'evoluSHEIN': 5,
#          'Cotton': 19,
#          'Mini': 9,
#          'Chiffon': 15,
#          'Key': 3,
#          'Hole': 3,
#          'Popover': 9,
#          'Chevron': 4,
#          'Sequin': 43,
#          'Round': 35,
#          'Simplee': 5,
#          'Low': 12,
#          'Swing': 4,
#          'Plunging': 59,
#          'Belle': 19,
#          'Surplice': 36,
#          'Slim': 37,
#          'Fit': 25,
#          'Exaggerate': 2,
#          'Jacquard': 23,
#          'Combo': 3,
#          'Laser': 3,
#          'Scalloped': 3,
#          'Fake': 9,
#          'Leaf': 9,
#          'Zebra': 10,
#          'Prom': 4,
#          'Armhole': 4,
#          'Long': 6,
#          'Cheeky': 5,
#          'Plant': 9,
#          'Cow': 5,
#          'Straps': 6,
#          'Overlay': 5,
#          '2': 13,
#          'In': 9,
#          '1': 9,
#          'Marble': 11,
#          'Edge': 2,
#          'Cuff': 24,
#          'Velvet': 19,
#          'Waistband': 5,
#          'Dolman': 15,
#          'Wideband': 7,
#          'Biker': 28,
#          'Strappy': 1,
#          'Open-Back': 1,
#          'Waistcoat': 2,
#          'Half': 36,
#          'Pom-pom': 3,
#          'Waffle': 15,
#          '4pack': 5,
#          'Mermaid': 11,
#          'Formal': 6,
#          'Rib-Knit': 2,
#          'Kangaroo': 18,
#          'Maxi': 18,
#          'Rise': 2,
#          'Tailored': 7,
#          'Palm': 6,
#          'Adjustable': 2,
#          'With': 28,
#          'Herringbone': 1,
#          'Peplum': 12,
#          'Bomber': 2,
#          'Placket': 11,
#          'Frayed': 8,
#          'Mom': 3,
#          'Pearls': 8,
#          'And': 31,
#          'Sew': 1,
#          'Babydoll': 5,
#          'Turtleneck': 19,
#          'Longline': 9,
#          'Boyfriend': 8,
#          'Wired': 8,
#          'Face': 5,
#          'Curved': 10,
#          'Vertical': 7,
#          'STPL': 9,
#          'Quarter': 9,
#          'Cricket': 3,
#          'Criss-cross': 14,
#          'Kawaii': 2,
#          'Cold': 22,
#          'Cable': 16,
#          'Bootcut': 10,
#          'Bra': 24,
#          '2pack': 3,
#          'Paper': 1,
#          'Bag': 1,
#          'Sequins': 12,
#          'Chunky': 3,
#          'Cowl': 6,
#          'Chain': 24,
#          'Roll': 14,
#          'Dandelion': 3,
#          'Ombre': 6,
#          'Light': 7,
#          'Washed': 9,
#          'Tied': 29,
#          'O-Ring': 2,
#          'Bandana': 18,
#          'Crossover': 3,
#          'Knitted': 8,
#          'Leaves': 3,
#          'Beach': 14,
#          'Deep': 7,
#          'Knotted': 7,
#          'Fishnet': 6,
#          'overlay': 2,
#          'Mountain': 8,
#          'Whipstitch': 3,
#          'Figure': 22,
#          'Openwork': 2,
#          'Eyelash': 1,
#          'Metallic': 14,
#          'Camo': 15,
#          'Smock': 48,
#          'Rhinestone': 31,
#          'Skeleton': 8,
#          'Hands': 2,
#          'Frilled': 5,
#          'Short': 7,
#          'Cutout': 36,
#          'Plicated': 15,
#          'Apperloth': 3,
#          'A': 4,
#          'Corset': 7,
#          'Suspender': 2,
#          'Stand': 11,
#          'Fuzzy': 11,
#          'Embroidered': 6,
#          'Cropped': 4,
#          'Turtle': 2,
#          'Corduroy': 10,
#          'Expression': 7,
#          'Patchwork': 5,
#          'Knee-Length': 1,
#          'Tulip': 9,
#          'Marled': 11,
#          'Phone': 1,
#          'Self-Tie': 9,
#          'Ruffled': 3,
#          'PARTHEA': 25,
#          'High-rise': 4,
#          'Trumpet': 8,
#          'Pop': 5,
#          'Art': 5,
#          'Bow': 7,
#          'Gingham': 7,
#          'Button-Front': 2,
#          'PUNK': 14,
#          'Grunge': 21,
#          'Skull': 6,
#          'Galaxy': 1,
#          'Checker': 2,
#          'Crew': 3,
#          '1pc': 22,
#          'Moustache': 2,
#          'Effect': 2,
#          'Self': 3,
#          'Plants': 9,
#          'Newspaper': 3,
#          'Off-The-Shoulder': 1,
#          'Blouson': 1,
#          'Dopamine': 4,
#          'Dressing': 4,
#          'Sailor': 1,
#          'Sun': 6,
#          'Palazzo': 4,
#          'Cuffed': 3,
#          'Tweed': 6,
#          'Form-Fitting': 7,
#          'Crazy': 6,
#          'Gigot': 11,
#          'Street': 5,
#          'Vibes': 5,
#          'Parachute': 6,
#          'Space': 3,
#          'Lingerie': 3,
#          'Cloud': 1,
#          'Stone': 2,
#          'High-Waisted': 1,
#          'Tassel': 5,
#          'Buckle': 5,
#          'Beaded': 4,
#          '3D': 2,
#          'Body': 5,
#          'Pack': 5,
#          'Cord': 3,
#          'Western': 8,
#          'Cowgirl': 6,
#          'High-Slit': 1,
#          'V-Neck': 7,
#          'Schiffy': 13,
#          'Cat': 3,
#          'See': 2,
#          'Through': 7,
#          'Sierra': 2,
#          'Siler': 2,
#          'Oversize': 5,
#          'Joyfunear': 12,
#          'Party': 5,
#          'Cap': 4,
#          'Academia': 1,
#          'Patent': 3,
#          'Decor': 14,
#          'Garter': 3,
#          '3sets': 1,
#          'Sweetness': 2,
#          'Stretch': 3,
#          'Glamaker': 2,
#          'and': 12,
#          'Neon': 4,
#          'Blue': 2,
#          'Faux': 4,
#          'Pearl': 4,
#          'Basketball': 3,
#          'MIUSOL': 1,
#          'Business': 1,
#          'Piping': 4,
#          'High-Rise': 6,
#          'Basic': 4,
#          'Bardot': 3,
#          'Slip': 3,
#          'Scarf': 1,
#          'Collared': 3,
#          'Camisole': 3,
#          'Roll-up': 1,
#          'Dinosaur': 5,
#          'Flannelette': 2,
#          'Tobefonseca': 2,
#          'Grommet': 3,
#          'Four': 1,
#          'Clover': 3,
#          'Paperbag': 10,
#          'Whisker': 2,
#          'Snakeskin': 6,
#          'Foldover': 2,
#          'Teddy': 11,
#          'Mandala': 1,
#          'Fleece': 4,
#          'Number': 2,
#          'Press': 2,
#          'Crease': 2,
#          'Hand': 4,
#          'Mock-Neck': 4,
#          'Paeka': 2,
#          'Eagle': 4,
#          'Cut-waist': 1,
#          'Cash': 1,
#          'Mock-neck': 2,
#          'Layer': 1,
#          'Coconut': 2,
#          'Tree': 8,
#          'Elephant': 1,
#          'Top-stitching': 5,
#          'Cloak': 1,
#          'Dazy-Less': 4,
#          'Fluffy': 3,
#          'Carrot': 1,
#          'Chinese': 2,
#          'Dragon': 2,
#          'Damask': 1,
#          'Wool-Mix': 1,
#          'Dr': 1,
#          'Speakup': 1,
#          'Animal': 1,
#          'Tartan': 1,
#          'Moto': 1,
#          'Pretty': 2,
#          'Bratty': 2,
#          'LOONEY': 1,
#          'TUNES': 1,
#          'Tapered': 3,
#          'The': 7,
#          'Borg': 1,
#          'Buckled': 1,
#          'Flocked': 1,
#          'Flared': 4,
#          'Confetti': 1,
#          'Splash': 1,
#          'Ink': 1,
#          'HELLFUNCO': 1,
#          '3': 1,
#          'Buttoned': 4,
#          'Appliques': 1,
#          'Tummy': 1,
#          'Control': 1,
#          'Flannel': 4,
#          'M-slit': 5,
#          'Studded': 2,
#          'Dr.kholoud': 1,
#          'Applique': 1,
#          'Vincenttrinidadart': 1,
#          'Japanese': 2,
#          'Stirrup': 1,
#          'Ringer': 1,
#          'Fruit': 1,
#          'Motorcycle': 2,
#          'Choker': 1,
#          'Mushroom': 3,
#          'MELIKE': 1,
#          'FIRAT': 1,
#          'Frog': 1,
#          'Mandarin': 1,
#          'Stitching': 2,
#          'Frida': 1,
#          'Kahlo': 1,
#          'Designer': 1,
#          'Metal': 2,
#          'Checked': 1,
#          'Ashley': 1,
#          'Baxter': 1,
#          'Arm': 2,
#          'Anime': 1,
#          'One-Piece': 1,
#          'SHEINBlues': 1,
#          'Middle-Waisted': 1,
#          'Halterneck': 7,
#          'Asymmetric': 2,
#          'Eilly': 2,
#          'Bazar': 2,
#          'American': 4,
#          'Flag': 4,
#          'Abstract': 2,
#          'Angel': 2,
#          'Rolled': 3,
#          'Spaceship': 2,
#          'Cactus': 3,
#          'ADYCE': 2,
#          'Wedding': 2,
#          'Guest': 2,
#          'Bandage': 2,
#          'Thumbholes': 2,
#          'GOLDENLINE': 2,
#          'Gathered': 4,
#          'Tanga': 2,
#          'AriGameplays': 1,
#          'Future': 2,
#          'LOLITA': 7,
#          'SOFIA': 7,
#          'Pad': 2,
#          'Pineapple': 2,
#          'Plisse': 3,
#          'Joggers': 3,
#          'Shell': 2,
#          'Mid-Rise': 2,
#          'Overalls': 2,
#          'Tab': 2,
#          'Orange': 1,
#          '4Pack': 1,
#          'D&M': 1,
#          'Wing': 2,
#          'Colorful': 3,
#          'Color-block': 3,
#          'Wave': 2,
#          'Moon': 3,
#          'Missord': 1,
#          'Buffalo': 1,
#          'Heat': 2,
#          'Map': 2,
#          'Fairycore': 2,
#          'Topstitching': 1,
#          'Brooch': 1,
#          'Pompom': 1,
#          'Stephanie': 1,
#          'Durant': 1,
#          'Peekaboo': 1,
#          'Skater': 1,
#          'T-Shirt': 1,
#          'Angle': 1,
#          'Line': 1,
#          'Shrug': 1,
#          'Hollow-out': 1,
#          'Curvy': 1,
#          'Milkmaid': 1,
#          'Sollinarry': 1,
#          'Dollar': 1,
#          'Sparkly': 1,
#          'Swim': 1,
#          'Varsity': 2,
#          'Underwired': 1,
#          'Slub': 1,
#          'Snap': 3,
#          'Double-Breasted': 1,
#          'Heather': 1,
#          'Grey': 1,
#          'Brush': 1,
#          'Semi-Cropped': 1,
#          'Bolero': 2,
#          'Wings': 1,
#          'Reflective': 1,
#          'Waterfall': 2,
#          'Suede': 2,
#          'Self-tie': 2,
#          'Rainbow': 2,
#          'Popper': 1,
#          'Building': 1,
#          'Organza': 2,
#          'EVER-PRETTY': 1,
#          'Fishtail': 1,
#          'Evening': 2,
#          'Gown': 1,
#          'Lime': 1,
#          'Sleeves': 1,
#          'Brief': 1,
#          'Bird': 1,
#          'Pointed': 1,
#          'Honeycomb': 1,
#          'Gowns': 1,
#          'up': 1,
#          'Sequince': 1})

# %%
data = cloth_word_count.most_common()

# %%
data
# Out:
# [('SHEIN', 1812),
#  ('Dress', 1385),
#  ('Print', 845),
#  ('Solid', 806),
#  ('Top', 775),
#  ('Neck', 772),
#  ('Sleeve', 668),
#  ('Shoulder', 638),
#  ('Hem', 567),
#  ('Crop', 547),
#  ('Tee', 499),
#  ('Floral', 490),
#  ('Bikini', 444),
#  ('Tie', 441),
#  ('Front', 424),
#  ('&', 420),
#  ('Cami', 419),
#  ('Drop', 419),
#  ('Swimsuit', 403),
#  ('SXY', 351),
#  ('EZwear', 304),
#  ('Ruffle', 285),
#  ('Trim', 284),
#  ('Waist', 283),
#  ('High', 275),
#  ('Bodycon', 263),
#  ('Halter', 263),
#  ('Ruched', 259),
#  ('Sweater', 253),
#  ('Up', 253),
#  ('Split', 251),
#  ('Blouse', 249),
#  ('Back', 247),
#  ('Knit', 244),
#  ('Cut', 242),
#  ('EMERY', 242),
#  ('ROSE', 242),
#  ('Backless', 239),
#  ('Tank', 228),
#  ('Graphic', 219),
#  ('Out', 203),
#  ('Unity', 202),
#  ('Pants', 199),
#  ('Leg', 185),
#  ('Skirt', 184),
#  ('Drawstring', 182),
#  ('Side', 180),
#  ('VCAY', 180),
#  ('Pocket', 179),
#  ('Button', 177),
#  ('Allover', 176),
#  ('Letter', 175),
#  ('Lace', 175),
#  ('Knot', 169),
#  ('Thigh', 165),
#  ('Jeans', 157),
#  ('Tube', 153),
#  ('BAE', 148),
#  ('Detail', 145),
#  ('Ribbed', 145),
#  ('Shorts', 144),
#  ('Belted', 143),
#  ('Zip', 141),
#  ('ICON', 138),
#  ('Ditsy', 137),
#  ('Mock', 136),
#  ('Contrast', 133),
#  ('DAZY', 127),
#  ('Mesh', 127),
#  ('Triangle', 125),
#  ('One', 125),
#  ('Twist', 123),
#  ('Batwing', 120),
#  ('Without', 119),
#  ('Flounce', 118),
#  ('Striped', 118),
#  ('Lantern', 115),
#  ('PETITE', 112),
#  ('Thermal', 109),
#  ('Wrap', 107),
#  ('Asymmetrical', 103),
#  ('Shirred', 100),
#  ('Bodysuit', 94),
#  ('Jumpsuit', 90),
#  ('Wide', 90),
#  ('Notched', 90),
#  ('Blazer', 88),
#  ('Cover', 87),
#  ('Sweatshirt', 86),
#  ('Shirt', 86),
#  ('Pattern', 85),
#  ('Puff', 85),
#  ('Collar', 81),
#  ('Lined', 80),
#  ('Hoodie', 79),
#  ('MOD', 78),
#  ('Rib-knit', 76),
#  ('Colorblock', 75),
#  ('Scoop', 74),
#  ('Flap', 74),
#  ('Satin', 74),
#  ('Ripped', 73),
#  ('Dot', 72),
#  ('Butterfly', 71),
#  ('Frill', 69),
#  ('Textured', 68),
#  ('Rib', 68),
#  ('Fitted', 67),
#  ('Open', 66),
#  ('Sweatpants', 65),
#  ('Tropical', 64),
#  ('Flare', 63),
#  ('Heart', 63),
#  ('Block', 63),
#  ('BASICS', 63),
#  ('Slogan', 62),
#  ('Color', 61),
#  ('V', 61),
#  ('Square', 61),
#  ('Plain', 60),
#  ('Cardigan', 59),
#  ('Plunging', 59),
#  ('Embroidery', 58),
#  ('Frenchy', 58),
#  ('Unitard', 55),
#  ('Plaid', 54),
#  ('Crisscross', 53),
#  ('Romper', 53),
#  ('Straight', 53),
#  ('Slant', 51),
#  ('Raw', 51),
#  ('Denim', 51),
#  ('Zipper', 50),
#  ('Slit', 50),
#  ('Linked', 49),
#  ('Off', 48),
#  ('A-line', 48),
#  ('Smock', 48),
#  ('Ring', 46),
#  ('Pleated', 45),
#  ('Set', 45),
#  ('Leopard', 44),
#  ('Lettuce', 44),
#  ('PU', 43),
#  ('Coat', 43),
#  ('Sequin', 43),
#  ('ROMWE', 42),
#  ('Guipure', 42),
#  ('Cross', 42),
#  ('Dye', 42),
#  ('Leather', 41),
#  ('Cargo', 40),
#  ('Keyhole', 40),
#  ('Panel', 39),
#  ('Bishop', 39),
#  ('Raglan', 39),
#  ('Jacket', 39),
#  ('Bust', 38),
#  ('Two', 38),
#  ('Tone', 38),
#  ('Random', 37),
#  ('Tall', 37),
#  ('Layered', 37),
#  ('Polka', 37),
#  ('Slim', 37),
#  ('Sheer', 36),
#  ('Shawl', 36),
#  ('Surplice', 36),
#  ('Half', 36),
#  ('Cutout', 36),
#  ('Smocked', 35),
#  ('Swiss', 35),
#  ('Sweetheart', 35),
#  ('Round', 35),
#  ('Skinny', 34),
#  ('X', 34),
#  ('Fringe', 34),
#  ('Tunic', 34),
#  ('Single', 32),
#  ('Vest', 32),
#  ('Oversized', 32),
#  ('Waisted', 32),
#  ('Leggings', 32),
#  ('Patched', 32),
#  ('Belt', 31),
#  ('Double', 31),
#  ('And', 31),
#  ('Rhinestone', 31),
#  ('Thong', 30),
#  ('Binding', 30),
#  ('Micro', 30),
#  ('Lapel', 30),
#  ('Bandeau', 30),
#  ('Bikinx', 30),
#  ('Insert', 30),
#  ('Pullover', 29),
#  ('Puffer', 29),
#  ('Criss', 29),
#  ('Tied', 29),
#  ('Draped', 28),
#  ('Elastic', 28),
#  ('Biker', 28),
#  ('With', 28),
#  ('Underwire', 27),
#  ('Sleeveless', 27),
#  ('BIZwear', 27),
#  ('Piece', 27),
#  ('Geo', 27),
#  ('Hollow', 26),
#  ('Form', 25),
#  ('Hooded', 25),
#  ('Fit', 25),
#  ('PARTHEA', 25),
#  ('Fly', 24),
#  ('Modely', 24),
#  ('Kimono', 24),
#  ('Breasted', 24),
#  ('Cut-out', 24),
#  ('Paisley', 24),
#  ('Cuff', 24),
#  ('Bra', 24),
#  ('Chain', 24),
#  ('Cartoon', 23),
#  ('Jacquard', 23),
#  ('Neckline', 22),
#  ('Hanky', 22),
#  ('Cold', 22),
#  ('Figure', 22),
#  ('1pc', 22),
#  ('3pack', 21),
#  ('Grunge', 21),
#  ('Bustier', 20),
#  ('Overall', 19),
#  ('Dual', 19),
#  ('Cotton', 19),
#  ('Belle', 19),
#  ('Velvet', 19),
#  ('Turtleneck', 19),
#  ('O-ring', 18),
#  ('Strap', 18),
#  ('Boat', 18),
#  ('Glitter', 18),
#  ('Kangaroo', 18),
#  ('Maxi', 18),
#  ('Bandana', 18),
#  ('Eyelet', 17),
#  ('Houndstooth', 16),
#  ('Pointelle', 16),
#  ('Cable', 16),
#  ('Crochet', 15),
#  ('Star', 15),
#  ('Super', 15),
#  ('Stripe', 15),
#  ('Pockets', 15),
#  ('Chiffon', 15),
#  ('Dolman', 15),
#  ('Waffle', 15),
#  ('Camo', 15),
#  ('Plicated', 15),
#  ('Bodice', 14),
#  ('Notch', 14),
#  ('Duster', 14),
#  ('3pcs', 14),
#  ('Dalmatian', 14),
#  ('90s', 14),
#  ('V-neck', 14),
#  ('Overlap', 14),
#  ('Criss-cross', 14),
#  ('Roll', 14),
#  ('Beach', 14),
#  ('Metallic', 14),
#  ('PUNK', 14),
#  ('Decor', 14),
#  ('Push', 13),
#  ('Track', 13),
#  ('Panty', 13),
#  ('2', 13),
#  ('Schiffy', 13),
#  ('Pencil', 12),
#  ('4pcs', 12),
#  ('Low', 12),
#  ('Peplum', 12),
#  ('Sequins', 12),
#  ('Joyfunear', 12),
#  ('and', 12),
#  ('Bell', 11),
#  ('Car', 11),
#  ('Suit', 11),
#  ('Marble', 11),
#  ('Mermaid', 11),
#  ('Placket', 11),
#  ('Stand', 11),
#  ('Fuzzy', 11),
#  ('Marled', 11),
#  ('Gigot', 11),
#  ('Teddy', 11),
#  ('Fold', 10),
#  ('Seam', 10),
#  ('Stitch', 10),
#  ('Scallop', 10),
#  ('Petal', 10),
#  ('Tape', 10),
#  ('Zebra', 10),
#  ('Curved', 10),
#  ('Bootcut', 10),
#  ('Corduroy', 10),
#  ('Paperbag', 10),
#  ('Hook', 9),
#  ('Eye', 9),
#  ('Mini', 9),
#  ('Popover', 9),
#  ('Fake', 9),
#  ('Leaf', 9),
#  ('Plant', 9),
#  ('In', 9),
#  ('1', 9),
#  ('Longline', 9),
#  ('STPL', 9),
#  ('Quarter', 9),
#  ('Washed', 9),
#  ('Tulip', 9),
#  ('Self-Tie', 9),
#  ('Plants', 9),
#  ('Flutter', 8),
#  ('Wash', 8),
#  ('Dobby', 8),
#  ('Frayed', 8),
#  ('Pearls', 8),
#  ('Boyfriend', 8),
#  ('Wired', 8),
#  ('Knitted', 8),
#  ('Mountain', 8),
#  ('Skeleton', 8),
#  ('Trumpet', 8),
#  ('Western', 8),
#  ('Tree', 8),
#  ('Feather', 7),
#  ('Wideband', 7),
#  ('Tailored', 7),
#  ('Vertical', 7),
#  ('Light', 7),
#  ('Deep', 7),
#  ('Knotted', 7),
#  ('Short', 7),
#  ('Corset', 7),
#  ('Expression', 7),
#  ('Bow', 7),
#  ('Gingham', 7),
#  ('Form-Fitting', 7),
#  ('V-Neck', 7),
#  ('Through', 7),
#  ('The', 7),
#  ('Halterneck', 7),
#  ('LOLITA', 7),
#  ('SOFIA', 7),
#  ('Look', 6),
#  ('Pads', 6),
#  ('Bleach', 6),
#  ('2pcs', 6),
#  ('Bottom', 6),
#  ('All', 6),
#  ('Over', 6),
#  ('Long', 6),
#  ('Straps', 6),
#  ('Formal', 6),
#  ('Palm', 6),
#  ('Cowl', 6),
#  ('Ombre', 6),
#  ('Fishnet', 6),
#  ('Embroidered', 6),
#  ('Skull', 6),
#  ('Sun', 6),
#  ('Tweed', 6),
#  ('Crazy', 6),
#  ('Parachute', 6),
#  ('Cowgirl', 6),
#  ('High-Rise', 6),
#  ('Snakeskin', 6),
#  ('Fluid', 5),
#  ('Hidden', 5),
#  ('Lace-up', 5),
#  ('Whip', 5),
#  ('evoluSHEIN', 5),
#  ('Simplee', 5),
#  ('Cheeky', 5),
#  ('Cow', 5),
#  ('Overlay', 5),
#  ('Waistband', 5),
#  ('4pack', 5),
#  ('Babydoll', 5),
#  ('Face', 5),
#  ('Frilled', 5),
#  ('Patchwork', 5),
#  ('Pop', 5),
#  ('Art', 5),
#  ('Street', 5),
#  ('Vibes', 5),
#  ('Tassel', 5),
#  ('Buckle', 5),
#  ('Body', 5),
#  ('Pack', 5),
#  ('Oversize', 5),
#  ('Party', 5),
#  ('Dinosaur', 5),
#  ('Top-stitching', 5),
#  ('M-slit', 5),
#  ('Cherry', 4),
#  ('Grid', 4),
#  ('Patch', 4),
#  ('Overcoat', 4),
#  ('Chevron', 4),
#  ('Swing', 4),
#  ('Prom', 4),
#  ('Armhole', 4),
#  ('A', 4),
#  ('Cropped', 4),
#  ('High-rise', 4),
#  ('Dopamine', 4),
#  ('Dressing', 4),
#  ('Palazzo', 4),
#  ('Beaded', 4),
#  ('Cap', 4),
#  ('Neon', 4),
#  ('Faux', 4),
#  ('Pearl', 4),
#  ('Piping', 4),
#  ('Basic', 4),
#  ('Fleece', 4),
#  ('Hand', 4),
#  ('Mock-Neck', 4),
#  ('Eagle', 4),
#  ('Dazy-Less', 4),
#  ('Flared', 4),
#  ('Buttoned', 4),
#  ('Flannel', 4),
#  ('American', 4),
#  ('Flag', 4),
#  ('Gathered', 4),
#  ('Distressed', 3),
#  ('Winter', 3),
#  ('Argyle', 3),
#  ('Thumb', 3),
#  ('Holes', 3),
#  ('Tankini', 3),
#  ('Glen', 3),
#  ('Key', 3),
#  ('Hole', 3),
#  ('Combo', 3),
#  ('Laser', 3),
#  ('Scalloped', 3),
#  ('Pom-pom', 3),
#  ('Mom', 3),
#  ('Cricket', 3),
#  ('2pack', 3),
#  ('Chunky', 3),
#  ('Dandelion', 3),
#  ('Crossover', 3),
#  ('Leaves', 3),
#  ('Whipstitch', 3),
#  ('Apperloth', 3),
#  ('Ruffled', 3),
#  ('Crew', 3),
#  ('Self', 3),
#  ('Newspaper', 3),
#  ('Cuffed', 3),
#  ('Space', 3),
#  ('Lingerie', 3),
#  ('Cord', 3),
#  ('Cat', 3),
#  ('Patent', 3),
#  ('Garter', 3),
#  ('Stretch', 3),
#  ('Basketball', 3),
#  ('Bardot', 3),
#  ('Slip', 3),
#  ('Collared', 3),
#  ('Camisole', 3),
#  ('Grommet', 3),
#  ('Clover', 3),
#  ('Fluffy', 3),
#  ('Tapered', 3),
#  ('Mushroom', 3),
#  ('Rolled', 3),
#  ('Cactus', 3),
#  ('Plisse', 3),
#  ('Joggers', 3),
#  ('Colorful', 3),
#  ('Color-block', 3),
#  ('Moon', 3),
#  ('Snap', 3),
#  ('Stacked', 2),
#  ('Funnel', 2),
#  ('Pinafore', 2),
#  ('Aurora', 2),
#  ('Celli', 2),
#  ('Ankle', 2),
#  ('U-ring', 2),
#  ('Trench', 2),
#  ('Exaggerate', 2),
#  ('Edge', 2),
#  ('Waistcoat', 2),
#  ('Rib-Knit', 2),
#  ('Rise', 2),
#  ('Adjustable', 2),
#  ('Bomber', 2),
#  ('Kawaii', 2),
#  ('O-Ring', 2),
#  ('overlay', 2),
#  ('Openwork', 2),
#  ('Hands', 2),
#  ('Suspender', 2),
#  ('Turtle', 2),
#  ('Button-Front', 2),
#  ('Checker', 2),
#  ('Moustache', 2),
#  ('Effect', 2),
#  ('Stone', 2),
#  ('3D', 2),
#  ('See', 2),
#  ('Sierra', 2),
#  ('Siler', 2),
#  ('Sweetness', 2),
#  ('Glamaker', 2),
#  ('Blue', 2),
#  ('Flannelette', 2),
#  ('Tobefonseca', 2),
#  ('Whisker', 2),
#  ('Foldover', 2),
#  ('Number', 2),
#  ('Press', 2),
#  ('Crease', 2),
#  ('Paeka', 2),
#  ('Mock-neck', 2),
#  ('Coconut', 2),
#  ('Chinese', 2),
#  ('Dragon', 2),
#  ('Pretty', 2),
#  ('Bratty', 2),
#  ('Studded', 2),
#  ('Japanese', 2),
#  ('Motorcycle', 2),
#  ('Stitching', 2),
#  ('Metal', 2),
#  ('Arm', 2),
#  ('Asymmetric', 2),
#  ('Eilly', 2),
#  ('Bazar', 2),
#  ('Abstract', 2),
#  ('Angel', 2),
#  ('Spaceship', 2),
#  ('ADYCE', 2),
#  ('Wedding', 2),
#  ('Guest', 2),
#  ('Bandage', 2),
#  ('Thumbholes', 2),
#  ('GOLDENLINE', 2),
#  ('Tanga', 2),
#  ('Future', 2),
#  ('Pad', 2),
#  ('Pineapple', 2),
#  ('Shell', 2),
#  ('Mid-Rise', 2),
#  ('Overalls', 2),
#  ('Tab', 2),
#  ('Wing', 2),
#  ('Wave', 2),
#  ('Heat', 2),
#  ('Map', 2),
#  ('Fairycore', 2),
#  ('Varsity', 2),
#  ('Bolero', 2),
#  ('Waterfall', 2),
#  ('Suede', 2),
#  ('Self-tie', 2),
#  ('Rainbow', 2),
#  ('Organza', 2),
#  ('Evening', 2),
#  ('Gold', 1),
#  ('Strappy', 1),
#  ('Open-Back', 1),
#  ('Herringbone', 1),
#  ('Sew', 1),
#  ('Paper', 1),
#  ('Bag', 1),
#  ('Eyelash', 1),
#  ('Knee-Length', 1),
#  ('Phone', 1),
#  ('Galaxy', 1),
#  ('Off-The-Shoulder', 1),
#  ('Blouson', 1),
#  ('Sailor', 1),
#  ('Cloud', 1),
#  ('High-Waisted', 1),
#  ('High-Slit', 1),
#  ('Academia', 1),
#  ('3sets', 1),
#  ('MIUSOL', 1),
#  ('Business', 1),
#  ('Scarf', 1),
#  ('Roll-up', 1),
#  ('Four', 1),
#  ('Mandala', 1),
#  ('Cut-waist', 1),
#  ('Cash', 1),
#  ('Layer', 1),
#  ('Elephant', 1),
#  ('Cloak', 1),
#  ('Carrot', 1),
#  ('Damask', 1),
#  ('Wool-Mix', 1),
#  ('Dr', 1),
#  ('Speakup', 1),
#  ('Animal', 1),
#  ('Tartan', 1),
#  ('Moto', 1),
#  ('LOONEY', 1),
#  ('TUNES', 1),
#  ('Borg', 1),
#  ('Buckled', 1),
#  ('Flocked', 1),
#  ('Confetti', 1),
#  ('Splash', 1),
#  ('Ink', 1),
#  ('HELLFUNCO', 1),
#  ('3', 1),
#  ('Appliques', 1),
#  ('Tummy', 1),
#  ('Control', 1),
#  ('Dr.kholoud', 1),
#  ('Applique', 1),
#  ('Vincenttrinidadart', 1),
#  ('Stirrup', 1),
#  ('Ringer', 1),
#  ('Fruit', 1),
#  ('Choker', 1),
#  ('MELIKE', 1),
#  ('FIRAT', 1),
#  ('Frog', 1),
#  ('Mandarin', 1),
#  ('Frida', 1),
#  ('Kahlo', 1),
#  ('Designer', 1),
#  ('Checked', 1),
#  ('Ashley', 1),
#  ('Baxter', 1),
#  ('Anime', 1),
#  ('One-Piece', 1),
#  ('SHEINBlues', 1),
#  ('Middle-Waisted', 1),
#  ('AriGameplays', 1),
#  ('Orange', 1),
#  ('4Pack', 1),
#  ('D&M', 1),
#  ('Missord', 1),
#  ('Buffalo', 1),
#  ('Topstitching', 1),
#  ('Brooch', 1),
#  ('Pompom', 1),
#  ('Stephanie', 1),
#  ('Durant', 1),
#  ('Peekaboo', 1),
#  ('Skater', 1),
#  ('T-Shirt', 1),
#  ('Angle', 1),
#  ('Line', 1),
#  ('Shrug', 1),
#  ('Hollow-out', 1),
#  ('Curvy', 1),
#  ('Milkmaid', 1),
#  ('Sollinarry', 1),
#  ('Dollar', 1),
#  ('Sparkly', 1),
#  ('Swim', 1),
#  ('Underwired', 1),
#  ('Slub', 1),
#  ('Double-Breasted', 1),
#  ('Heather', 1),
#  ('Grey', 1),
#  ('Brush', 1),
#  ('Semi-Cropped', 1),
#  ('Wings', 1),
#  ('Reflective', 1),
#  ('Popper', 1),
#  ('Building', 1),
#  ('EVER-PRETTY', 1),
#  ('Fishtail', 1),
#  ('Gown', 1),
#  ('Lime', 1),
#  ('Sleeves', 1),
#  ('Brief', 1),
#  ('Bird', 1),
#  ('Pointed', 1),
#  ('Honeycomb', 1),
#  ('Gowns', 1),
#  ('up', 1),
#  ('Sequince', 1)]

# %%
keyword_df = pd.DataFrame(data, columns = ["Keyword","Frequency"])

# %%
keyword_df
# Out:
#        Keyword  Frequency
# 0        SHEIN       1812
# 1        Dress       1385
# 2        Print        845
# 3        Solid        806
# 4          Top        775
# ..         ...        ...
# 691    Pointed          1
# 692  Honeycomb          1
# 693      Gowns          1
# 694         up          1
# 695   Sequince          1
#
# [696 rows x 2 columns]

# %%
keyword_df.to_csv("Shein_keywords.csv",index = False)
