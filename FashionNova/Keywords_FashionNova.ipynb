# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
file_path = r"C:\Users\Braydon\Desktop\Shein_Data\Pivot_Data\FashionNova\FashionNova_Data_output.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#       Column1                                         Cloth_Desc  Price
# 0           0       Classic High Waist Skinny Jeans - Dark Denim  24.99
# 1           1  Classic High Waist Skinny Jeans - Medium Blue ...  24.99
# 2           2            Super High Waist Denim Skinnies - Black  24.99
# 3           3                               Canopy Jeans - Black  24.99
# 4           4  Classic High Waist Skinny Jeans - Light Blue Wash  24.99
# ...       ...                                                ...    ...
# 6025     6025                       The New Look Joggers - Olive   5.98
# 6026     6026          When I Lose Control Satin Corset - Orange   8.98
# 6027     6027                             Daylight Romper - Nude   8.98
# 6028     6028  Alessandra Cable Knit Duster Cardigan - Heathe...  39.99
# 6029     6029               Checking In Plaid Pants - Grey/combo  19.99
#
# [6030 rows x 3 columns]

# %%
cloth_word_lst = []

for item in df['Cloth_Desc']:
    item = item.split()
    for thing in item:
        cloth_word_lst.append(thing)

# %%
cloth_word_count = Counter(cloth_word_lst)

# %%
cloth_word_count
# Out:
# Counter({'Classic': 48,
#          'High': 309,
#          'Waist': 59,
#          'Skinny': 298,
#          'Jeans': 837,
#          '-': 6022,
#          'Dark': 207,
#          'Denim': 202,
#          'Medium': 319,
#          'Blue': 482,
#          'Wash': 475,
#          'Super': 45,
#          'Skinnies': 11,
#          'Black': 1757,
#          'Canopy': 9,
#          'Light': 195,
#          'Supernatural': 4,
#          'Rise': 240,
#          'The': 459,
#          'Glass': 17,
#          'Slipper': 7,
#          'Transparent': 2,
#          'Coraline': 2,
#          'Nova': 34,
#          'Season': 29,
#          'Jumpsuit': 343,
#          'White': 325,
#          'Glistening': 6,
#          'Almost': 6,
#          'Every': 7,
#          'Day': 37,
#          'Leggings': 117,
#          'Say': 12,
#          'Yes': 14,
#          'To': 163,
#          'Distress': 12,
#          'Natalee': 15,
#          'Biker': 165,
#          'Shorts': 101,
#          'Indigo': 11,
#          'Drive': 6,
#          'Ocean': 7,
#          'Brooke': 8,
#          'Mid': 29,
#          'Beach': 28,
#          'Bum': 4,
#          'Buenos': 22,
#          'Aires': 22,
#          'Romper': 187,
#          'Heather': 135,
#          'Grey': 206,
#          'I': 62,
#          'Got': 32,
#          'It': 254,
#          'From': 20,
#          'My': 190,
#          'Mama': 5,
#          'First': 13,
#          'Pick': 6,
#          "Can't": 30,
#          'Believe': 5,
#          'It!': 1,
#          'Booty': 76,
#          'Shaping': 20,
#          'Jeans-': 1,
#          'Your': 176,
#          'Needs': 12,
#          'Met': 13,
#          'Dress': 1326,
#          'Cadet': 15,
#          'Kim': 7,
#          'Oversized': 38,
#          'Camo': 34,
#          'Pants': 190,
#          'Spree': 5,
#          'Since': 4,
#          'One': 83,
#          'Seamless': 28,
#          'Victoria': 16,
#          'Waisted': 37,
#          'Deep': 12,
#          'In': 211,
#          'Soul': 13,
#          'Flare': 102,
#          'Soothe': 7,
#          'Off': 151,
#          'Shoulder': 120,
#          'Distracted': 3,
#          'Hug': 5,
#          'So': 49,
#          'Tight': 7,
#          'Jodeci': 1,
#          'Wanderlust': 20,
#          'Too': 22,
#          'Much': 7,
#          'Low': 23,
#          'Marilyn': 4,
#          'Boost': 2,
#          'Lola': 4,
#          'Uncomplicated': 6,
#          'On': 157,
#          'Daily': 4,
#          'Sunshine': 7,
#          'See': 34,
#          'Through': 20,
#          'Cover': 50,
#          'Up': 196,
#          'Pant': 185,
#          'Tris': 3,
#          'Olive': 158,
#          'Hannah': 3,
#          'Running': 13,
#          'Around': 40,
#          'Legging': 123,
#          'Rose': 50,
#          'Gold': 262,
#          'Well': 9,
#          'Played': 6,
#          'Jacklyn': 7,
#          'Mini': 407,
#          'Oatmeal': 8,
#          'Charcoal': 68,
#          'Lose': 10,
#          'it': 5,
#          'All': 103,
#          'Heel': 50,
#          'Kahula': 1,
#          'Perfectly': 4,
#          'Edges': 8,
#          'That': 43,
#          'Scratch': 9,
#          'Bodysuit': 239,
#          'Killing': 7,
#          "'Em": 9,
#          'Kindly': 4,
#          'Work': 15,
#          'Of': 125,
#          'Art': 10,
#          'Red/Multi': 2,
#          'Flex': 12,
#          'Game': 27,
#          'Strong': 13,
#          'Faux': 54,
#          'Leather': 68,
#          'Tummy': 5,
#          'Tuck': 4,
#          'Sammie': 4,
#          'Fool': 9,
#          'Love': 137,
#          'Kallan': 10,
#          'Knit': 39,
#          'of': 12,
#          'the': 16,
#          'Boys': 7,
#          'No': 48,
#          'Good': 34,
#          'For': 99,
#          'Each': 1,
#          'Other': 8,
#          'Fantasea': 1,
#          'Nights': 19,
#          'Favorite': 33,
#          'Short': 189,
#          'Tempe': 3,
#          'Distressed': 122,
#          'Needing': 6,
#          'Something': 10,
#          'Remedy': 4,
#          'Everything': 18,
#          'Our': 6,
#          'Catty': 3,
#          "Let's": 10,
#          'Get': 53,
#          'Carried': 1,
#          'Away': 23,
#          'Lifter': 14,
#          'Knot': 21,
#          'Girl': 67,
#          'Dream': 16,
#          'Are': 15,
#          'We': 10,
#          'Clear': 43,
#          'Sandal': 41,
#          'Curves': 17,
#          'Days': 26,
#          'Plain': 4,
#          'Jane': 5,
#          'Just': 47,
#          'Might': 3,
#          'Nanette': 1,
#          'Bondoc': 8,
#          'Set': 615,
#          'Hit': 6,
#          'Freeway': 2,
#          'Fleece': 20,
#          'Lifting': 24,
#          'Stole': 27,
#          "Boyfriend's": 27,
#          'Jogger': 84,
#          'Hoodie': 78,
#          'Maura': 4,
#          'Mesh': 109,
#          'Pretty': 7,
#          'Thigh': 6,
#          'Boots': 16,
#          'Heaven': 2,
#          'Sent': 1,
#          'Sugar': 17,
#          'Free': 20,
#          'Teenage': 3,
#          'Fever': 4,
#          'Everywhere': 4,
#          'Luxe': 6,
#          'Fast': 7,
#          'Henley': 4,
#          'Shanghai': 7,
#          'Ruched': 176,
#          'Latest': 25,
#          'And': 134,
#          'Greatest': 26,
#          'French': 27,
#          'Terry': 28,
#          'Boot': 35,
#          'Camp': 5,
#          'Skirt': 181,
#          'Blanched': 2,
#          'Kalley': 3,
#          'Cargo': 58,
#          'Katie': 7,
#          'Cami': 6,
#          'Slip': 14,
#          'Talk': 23,
#          'Top': 292,
#          'A': 199,
#          'Wave': 8,
#          'Ready': 31,
#          'Ruffle': 21,
#          'Happy': 16,
#          'Hour': 14,
#          'Dare': 12,
#          'Devil': 4,
#          'Kylie': 1,
#          'Liliana': 4,
#          'Beverly': 5,
#          'Hills': 4,
#          'Tunic': 26,
#          'Mocha': 77,
#          'You': 284,
#          'Ankle': 59,
#          'Full': 8,
#          'Grown': 4,
#          'Sophie': 3,
#          'Jegging': 2,
#          'Go': 52,
#          'Extra': 6,
#          'Mile': 6,
#          'Active': 23,
#          'Effortless': 8,
#          'Ella': 2,
#          'Jean': 36,
#          'Nita': 6,
#          'Ribbed': 97,
#          'Cardigan': 60,
#          'Menace': 1,
#          'Basic': 29,
#          'Nude': 122,
#          'Plot': 4,
#          'Twist': 13,
#          'Mulberry': 9,
#          'Street': 13,
#          'Maxi': 144,
#          'Valentina': 5,
#          'Oooh': 2,
#          'Little': 22,
#          'Miss': 12,
#          "Don't": 89,
#          'This': 31,
#          'Twisted': 22,
#          'Heavy': 3,
#          'Relaxed': 33,
#          'Vibe': 37,
#          'Joggers': 57,
#          'Sex': 4,
#          'Magic': 5,
#          'Right': 27,
#          'Angle': 2,
#          'Kora': 5,
#          'Midi': 279,
#          'Make': 36,
#          'Some': 12,
#          'Noise': 1,
#          'Flame': 7,
#          'Heart': 47,
#          'Give': 23,
#          'Emma': 8,
#          'Stretch': 35,
#          'Melanie': 11,
#          'String': 2,
#          'Along': 3,
#          'Navy': 83,
#          'Taupe': 94,
#          'Burgundy': 121,
#          'Anna': 7,
#          'Nature': 2,
#          'Made': 7,
#          'Always': 37,
#          'Leaving': 2,
#          'Ultra': 4,
#          'Wifey': 4,
#          'Calidan': 1,
#          'Glam': 3,
#          'Party': 16,
#          'Monster': 2,
#          'Strapped': 2,
#          'Success': 2,
#          'Uniform': 3,
#          'Khaki': 25,
#          'Long': 55,
#          'Sleeve': 78,
#          'Multi': 67,
#          'Color': 33,
#          'Body': 32,
#          'Moves': 15,
#          'Keep': 58,
#          'Falls': 8,
#          'Sweater': 284,
#          'II': 30,
#          'Jojo': 3,
#          'Isabella': 2,
#          'Mauve': 106,
#          'Tea': 1,
#          'Leaf': 2,
#          'Ring': 28,
#          'Whole': 4,
#          'Lotta': 4,
#          'Class': 5,
#          'Satin': 73,
#          'Jessica': 1,
#          'Take': 39,
#          'Mind': 28,
#          'Baby': 27,
#          'Back': 56,
#          'Frisky': 7,
#          'Feline': 9,
#          'Beauty': 16,
#          'Hunter': 28,
#          'Green': 30,
#          'Sedona': 2,
#          'Do': 21,
#          'Dance': 3,
#          'Feather': 2,
#          'Weather': 2,
#          'Sliders': 7,
#          'Choker': 23,
#          'Silver': 76,
#          'Eva': 7,
#          'Soft': 21,
#          'Curvy': 7,
#          'Brianne': 1,
#          'Shake': 6,
#          'Thing': 10,
#          'Shortie': 5,
#          'Chase': 13,
#          'Bag': 11,
#          'Stacked': 27,
#          'Late': 8,
#          'Night': 54,
#          'Texts': 3,
#          'Vinyl': 6,
#          'Selah': 2,
#          'Hoop': 42,
#          'Earrings': 78,
#          'Brunch': 2,
#          'Date': 13,
#          'Shadow': 2,
#          'Olivia': 4,
#          'Meet': 24,
#          'Me': 336,
#          'Club': 4,
#          'Ivory': 85,
#          'With': 66,
#          'Heels': 40,
#          'Tell': 13,
#          'Boy': 7,
#          'Bye': 5,
#          'Pump': 10,
#          'Tokyo': 12,
#          'Smooth': 13,
#          'Operator': 4,
#          'Sleek': 8,
#          'Slay': 14,
#          'Net': 7,
#          'and': 16,
#          'Chill': 36,
#          'GiGi': 2,
#          'Toe': 7,
#          'Zephyr': 1,
#          'Drama': 6,
#          'Carlibell': 1,
#          'Caliente': 3,
#          'Grind': 15,
#          'Time': 49,
#          'Beyond': 7,
#          'MediumBlueWash': 1,
#          'Alexa': 2,
#          'Red': 162,
#          'Everyday': 12,
#          'Passionate': 3,
#          'Miles': 4,
#          'Adrial': 1,
#          'Double': 21,
#          'Camel': 20,
#          'Devan': 2,
#          'Tori': 5,
#          'Nicola': 1,
#          'Lace': 52,
#          'Button': 18,
#          'Tara': 8,
#          'Turtle': 20,
#          'Neck': 47,
#          'Turbo': 2,
#          'Vicky': 2,
#          'Over': 42,
#          'Knee': 14,
#          'Complicated': 1,
#          'Pomona': 1,
#          'Alone': 4,
#          'Out': 84,
#          'Nirvana': 2,
#          'Frenzy': 5,
#          'Be': 52,
#          'Square': 22,
#          'Chelsea': 14,
#          "I'll": 4,
#          'Ezra': 2,
#          'Gotta': 8,
#          'Have': 12,
#          'Edge': 6,
#          'Heeled': 56,
#          'Stir': 2,
#          'Tobi': 1,
#          'Mom': 33,
#          'Midnight': 6,
#          'Lover': 25,
#          'Snake': 23,
#          'Aviator': 4,
#          'Babe': 29,
#          'His': 9,
#          'Head': 25,
#          'Lhasa': 2,
#          "Payin'": 8,
#          'Forward': 8,
#          'Blazer': 18,
#          'Cut': 40,
#          'Hot': 20,
#          'Pink': 76,
#          'Carla': 4,
#          'Oh': 17,
#          'Fresh': 8,
#          'Pair': 2,
#          'Royal': 24,
#          'Swing': 2,
#          'Way': 52,
#          'Velvet': 22,
#          'Wine': 37,
#          'Rhianna': 9,
#          'Tube': 39,
#          'Play': 24,
#          'By': 21,
#          'Hopes': 3,
#          'Louise': 6,
#          'V': 15,
#          'Coat': 1,
#          'Feel': 8,
#          'Anything': 14,
#          'But': 19,
#          'Print': 18,
#          'Scarf': 17,
#          'Beige': 16,
#          'Jax': 1,
#          'Boyfriend': 52,
#          'Minimalistic': 1,
#          'Softly': 4,
#          'Side': 28,
#          'Split': 8,
#          'Tubular': 4,
#          'Leopard': 57,
#          'Brown/Combo': 4,
#          'Hong': 4,
#          'Kong': 4,
#          'Holy': 5,
#          'Slit': 18,
#          'Navy/Taupe': 1,
#          'Borrowed': 2,
#          'Hearts': 6,
#          'Mingle': 2,
#          'Bodycon': 14,
#          'Want': 17,
#          'PU': 16,
#          'Floral': 30,
#          'Flowers': 7,
#          'Chocolate': 48,
#          'Level': 4,
#          'Sage': 17,
#          'Hoops': 2,
#          'Like': 40,
#          'What': 34,
#          'Ripped': 10,
#          'Weekend': 18,
#          'Vibes': 29,
#          'Pro': 6,
#          'Lounger': 7,
#          'As': 18,
#          'If': 9,
#          'Khloe': 1,
#          'Sensor': 1,
#          'Evil': 2,
#          'Queen': 19,
#          'Warrior': 1,
#          'Sigh': 4,
#          'Aubrey': 1,
#          'Venetian': 1,
#          'Statuesque': 3,
#          'Tough': 3,
#          'Luck': 3,
#          'Fall': 9,
#          'Holder': 5,
#          'Shine': 19,
#          'Sequin': 70,
#          'Blush': 31,
#          'Giving': 7,
#          'Feels': 13,
#          'Precious': 4,
#          'Fit': 24,
#          'Katherine': 2,
#          'Post': 3,
#          'Gym': 3,
#          'Selfie': 3,
#          'Biggest': 2,
#          'Fan': 2,
#          'Affair': 7,
#          'Between': 5,
#          'Us': 8,
#          'Better': 26,
#          'Cognac': 16,
#          'Clink': 2,
#          'Janel': 1,
#          'Roll': 11,
#          'Into': 15,
#          'Layer': 1,
#          'Anklet': 34,
#          'Crossover': 6,
#          'Straight': 29,
#          'Leg': 55,
#          'Stud': 10,
#          'Berry': 3,
#          'Earring': 5,
#          "She's": 13,
#          'Fire': 8,
#          'Teyana': 3,
#          'Alter': 3,
#          'Ego': 8,
#          'Than': 20,
#          'Ever': 7,
#          'Groove': 3,
#          'Trouble': 6,
#          'Fishnets': 1,
#          'Socks': 23,
#          'Round': 8,
#          'Applause': 6,
#          'Shaped': 6,
#          'Rachel': 3,
#          'Racerback': 3,
#          'Olive/Navy': 1,
#          'Brown': 88,
#          'Come': 26,
#          'Very': 4,
#          'Special': 7,
#          'Anne': 8,
#          'Marie': 8,
#          'Butter': 1,
#          'Squat': 2,
#          'San': 1,
#          'Antonio': 1,
#          'Rest': 7,
#          'Oil': 8,
#          'Sunday': 5,
#          'Kind': 5,
#          'Duster': 14,
#          'Jacket': 14,
#          'Tennis': 9,
#          'Alyse': 1,
#          'Wish': 7,
#          "Jumpin'": 1,
#          'Plum': 13,
#          'Marja': 2,
#          'Stormy': 1,
#          'Bennie': 1,
#          'Caught': 9,
#          'Lil': 1,
#          'Bling': 4,
#          "I'm": 20,
#          'Magenta': 5,
#          'She': 12,
#          'Bad': 21,
#          'Salem': 1,
#          'At': 31,
#          'Spot': 14,
#          'Hermosa': 1,
#          'Mariposa': 1,
#          'Butterfly': 26,
#          'Amelia': 1,
#          'Alika': 1,
#          'Tank': 21,
#          'Next': 13,
#          'Glimpse': 2,
#          'An': 7,
#          'Eye': 12,
#          'Keepin': 2,
#          'Stressed': 1,
#          'Sexy': 11,
#          'More': 20,
#          'Story': 6,
#          'Doubt': 1,
#          'Trend': 6,
#          'Printed': 14,
#          'Camouflage': 12,
#          'Living': 24,
#          '3': 48,
#          'Piece': 108,
#          'Fray': 9,
#          'Mean': 8,
#          'Army': 2,
#          'Here': 23,
#          'Wedge': 3,
#          'List': 4,
#          'Bar': 4,
#          'Hopping': 1,
#          'Necklace': 78,
#          'Sight': 5,
#          'to': 3,
#          'Mariah': 2,
#          'Nice': 7,
#          'Brielle': 1,
#          'Portrait': 2,
#          'Let': 25,
#          'Smarty': 1,
#          'Kiki': 8,
#          'Pleather': 1,
#          'Cropped': 16,
#          'Did': 4,
#          'Black/Black': 5,
#          'Number': 4,
#          'Brand': 2,
#          'Spanking': 2,
#          'New': 30,
#          'Jessie': 2,
#          'Bootcut': 3,
#          'Euphoria': 8,
#          'Bikini': 89,
#          'Look': 29,
#          'Ray': 1,
#          'Solid': 7,
#          'Buffy': 1,
#          'Mysterious': 2,
#          'Gal': 3,
#          'Grace': 4,
#          'Fuck': 4,
#          'White/Black': 20,
#          'Seeing': 5,
#          'Belt': 38,
#          'Posh': 1,
#          'Jump': 3,
#          'Sweet': 30,
#          'Dreams': 30,
#          'Mineral': 6,
#          'Slide': 13,
#          'Block': 19,
#          'Olive/Combo': 4,
#          'Chosen': 3,
#          'Start': 9,
#          'Show': 26,
#          'Sealed': 1,
#          'Envelope': 2,
#          'Ponte': 8,
#          'Mustard': 50,
#          'Tan': 24,
#          'Air': 2,
#          'Linked': 1,
#          'Chain': 29,
#          'Hairs': 1,
#          'Mess': 4,
#          'Found': 4,
#          'Ya': 3,
#          'Flip': 4,
#          'Simple': 20,
#          'Perfection': 4,
#          'Brown/combo': 37,
#          'Own': 5,
#          'Raining': 1,
#          'Daisies': 1,
#          'Casual': 23,
#          'Feeling': 23,
#          'Fancy': 3,
#          'Collar': 3,
#          'Call': 21,
#          'Even': 6,
#          'Wide': 22,
#          'There': 7,
#          'Or': 14,
#          'Sunglasses': 91,
#          'Falling': 7,
#          'Charm': 2,
#          'Bold': 5,
#          'Statement': 2,
#          'Main': 2,
#          'Squeeze': 1,
#          'Wrong': 5,
#          'Hillcrest': 1,
#          'Spotless': 5,
#          'Coco': 3,
#          "X's": 2,
#          "O's": 2,
#          'Cowl': 8,
#          'Hearted': 4,
#          'Lift': 2,
#          'Tall': 22,
#          'Stay': 28,
#          'Line': 9,
#          'Kinley': 3,
#          'Matching': 7,
#          'Rydell': 2,
#          'Homegirl': 1,
#          'Layered': 16,
#          'Bounce': 4,
#          'Essential': 7,
#          'Black/Tan': 2,
#          'Watch': 10,
#          'Stories': 2,
#          'Swim': 20,
#          'Klum': 3,
#          'Ruby': 2,
#          'Moments': 14,
#          'After': 12,
#          'Treat': 3,
#          'Natural': 7,
#          'Lean': 5,
#          'Maisie': 1,
#          'Birthday': 4,
#          'Bash': 1,
#          'Best': 32,
#          'Sandals': 70,
#          'Highly': 3,
#          'Classified': 3,
#          'Rosie': 4,
#          'Tie': 118,
#          'Painting': 1,
#          'Pictures': 1,
#          'Prescott': 1,
#          "Backin'": 3,
#          'Plaid': 31,
#          'Yellow': 30,
#          'Carina': 1,
#          'Die': 5,
#          'Pullover': 14,
#          'Distance': 2,
#          "Stuntin'": 2,
#          'These': 2,
#          'Toes': 2,
#          'Blessings': 4,
#          'Dropping': 3,
#          'Hints': 2,
#          'Schedule': 5,
#          'Kendall': 2,
#          'Flared': 1,
#          'Ivory/Royal': 1,
#          'Adorn': 4,
#          'CEO': 2,
#          'Fort': 1,
#          'Worth': 3,
#          'TNT': 3,
#          'Dolman': 2,
#          'Daze': 5,
#          'Hyperstretch': 2,
#          'Sweatpants': 23,
#          'Celena': 1,
#          'Center': 4,
#          'Beret': 4,
#          'Smiley': 2,
#          'Dinner': 6,
#          'Innocent': 2,
#          'Karly': 3,
#          'Bae': 7,
#          'Irreplaceable': 1,
#          'Metallic': 10,
#          'Black/Copper': 1,
#          'Gonna': 2,
#          'Different': 5,
#          'Express': 1,
#          'Nothing': 8,
#          'Can': 25,
#          'Ice': 2,
#          'Three': 4,
#          'Grey/Orange': 1,
#          'Run': 11,
#          'Lucite': 1,
#          'Mule': 1,
#          'Keeping': 11,
#          'Secrets': 7,
#          'Coverage': 2,
#          'Sunrise': 1,
#          'Mornings': 1,
#          'Vintage': 11,
#          'Enough': 7,
#          'Because': 3,
#          'Said': 5,
#          'Destroyed': 7,
#          'Looking': 11,
#          'Bubble': 1,
#          'Butt': 2,
#          'Overtime': 1,
#          'Sneaker': 9,
#          'Maddy': 3,
#          'Type': 6,
#          'Beige/Black': 1,
#          'Isa': 1,
#          "C'ing": 1,
#          'Envy': 3,
#          'Moto': 7,
#          'Totally': 3,
#          'F': 2,
#          'Cassie': 1,
#          'Elastic': 1,
#          'Waistband': 1,
#          'Break': 14,
#          'Carpenter': 6,
#          'Bestie': 3,
#          'Glimmer': 2,
#          'Glow': 4,
#          'White/Pink': 5,
#          'Switch': 5,
#          'Gears': 5,
#          'Zhana': 1,
#          'Need': 27,
#          'Bossing': 1,
#          'Greyson': 1,
#          'Goin': 1,
#          'Down': 47,
#          'Tonight': 7,
#          'Sculpting': 16,
#          'Coated': 2,
#          'Reagan': 1,
#          'Again': 16,
#          'Eyes': 11,
#          'Owning': 2,
#          'Moment': 15,
#          'Jaysmin': 1,
#          'Decadence': 1,
#          'Babygirl': 1,
#          'Domesticated': 1,
#          'Cheetah': 1,
#          'Tianna': 1,
#          'Digging': 1,
#          'Feelin': 4,
#          'Grey/combo': 5,
#          'Honey': 12,
#          'Turn': 2,
#          'Changing': 2,
#          'Rhythms': 1,
#          'Gerrit': 1,
#          'Paige': 1,
#          'LightBlueWash': 1,
#          'Dragon': 4,
#          'Tattoos': 1,
#          'Taupe/combo': 14,
#          'True': 12,
#          'Icon': 3,
#          'Jodie': 5,
#          'Chilled': 4,
#          'Temperance': 1,
#          'Myina': 3,
#          'Criss': 3,
#          'Cross': 21,
#          'Dye': 105,
#          'Rust': 51,
#          'Yeah': 2,
#          'Fawn': 1,
#          'Kia': 1,
#          'Fleek': 2,
#          'Snatch': 2,
#          'Scottsdale': 1,
#          'Kiko': 1,
#          'Lifestyle': 3,
#          'Him': 7,
#          'Boho': 4,
#          'Black/White': 69,
#          'When': 8,
#          'Pencil': 2,
#          'Sayings': 1,
#          'Puppy': 6,
#          'Everlong': 1,
#          'Cheeks': 2,
#          'Gray': 2,
#          'Matter': 5,
#          'Rayna': 1,
#          'Crossing': 2,
#          'Paths': 1,
#          'Isabela': 2,
#          'Rhinestone': 35,
#          'Never': 34,
#          'Studded': 9,
#          'Sister': 3,
#          'Flat': 47,
#          'Pleasure': 1,
#          'Gems': 1,
#          'Please': 9,
#          'Rough': 1,
#          'Rider': 3,
#          'Katt': 2,
#          'Innocence': 2,
#          'Mint': 11,
#          'Focus': 5,
#          'Task': 4,
#          'Wait': 8,
#          'Bit': 3,
#          'Longer': 5,
#          'Booties': 18,
#          'Cara': 3,
#          'Platinum': 1,
#          'Status': 8,
#          'Ops': 1,
#          'Stone': 11,
#          'Zip': 23,
#          'Switching': 1,
#          'Angles': 1,
#          'Jeggings': 1,
#          'Catch': 5,
#          'Offline': 1,
#          'Black/Brown': 6,
#          'Perfect': 11,
#          'Tropical': 13,
#          'Red/combo': 8,
#          'Ajay': 3,
#          'Mona': 3,
#          'Dusty': 9,
#          'Wishful': 1,
#          'Thinking': 4,
#          'Carine': 1,
#          'Built': 1,
#          'Comfort': 15,
#          'Chasing': 5,
#          'Waterfalls': 2,
#          'Arms': 5,
#          'Ancient': 4,
#          'Rome': 4,
#          'Throwback': 1,
#          'Gigi': 3,
#          'Flow': 8,
#          'Heat': 6,
#          'Blue/combo': 22,
#          'Sparks': 1,
#          'Flying': 5,
#          'Flirtationship': 2,
#          'Two': 14,
#          'Flaunting': 1,
#          'Not': 42,
#          'Usually': 1,
#          'Stack': 1,
#          'Em': 3,
#          'About': 18,
#          'Black/Red': 10,
#          'Promises': 3,
#          'Cassey': 1,
#          'Pleated': 9,
#          'Lansa': 2,
#          'Bandage': 24,
#          "Twerkin'": 1,
#          "Workin'": 1,
#          'Stripe': 20,
#          'Wild': 21,
#          'Peria': 1,
#          'Jewel': 1,
#          'Needy': 4,
#          'Orange': 45,
#          'Zoe': 5,
#          'Pocket': 5,
#          'Dana': 4,
#          'Libra': 3,
#          'Mason': 2,
#          'Walk': 18,
#          'Behind': 1,
#          'Aim': 1,
#          'Adanna': 1,
#          'Winter': 1,
#          'Exposure': 1,
#          'Stage': 3,
#          'Aria': 2,
#          'Neon': 44,
#          'Brandy': 3,
#          'Stina': 1,
#          ...})

# %%
data = cloth_word_count.most_common()

# %%
data
# Out:
# [('-', 6022),
#  ('Black', 1757),
#  ('Dress', 1326),
#  ('Jeans', 837),
#  ('Set', 615),
#  ('Blue', 482),
#  ('Wash', 475),
#  ('The', 459),
#  ('Mini', 407),
#  ('Jumpsuit', 343),
#  ('Me', 336),
#  ('White', 325),
#  ('Medium', 319),
#  ('High', 309),
#  ('Skinny', 298),
#  ('Top', 292),
#  ('You', 284),
#  ('Sweater', 284),
#  ('Midi', 279),
#  ('Gold', 262),
#  ('It', 254),
#  ('Rise', 240),
#  ('Bodysuit', 239),
#  ('In', 211),
#  ('Dark', 207),
#  ('Grey', 206),
#  ('Denim', 202),
#  ('A', 199),
#  ('Up', 196),
#  ('Light', 195),
#  ('My', 190),
#  ('Pants', 190),
#  ('Short', 189),
#  ('Romper', 187),
#  ('Pant', 185),
#  ('Skirt', 181),
#  ('Your', 176),
#  ('Ruched', 176),
#  ('Biker', 165),
#  ('To', 163),
#  ('Red', 162),
#  ('Olive', 158),
#  ('On', 157),
#  ('Off', 151),
#  ('Maxi', 144),
#  ('Love', 137),
#  ('Heather', 135),
#  ('And', 134),
#  ('Of', 125),
#  ('Legging', 123),
#  ('Distressed', 122),
#  ('Nude', 122),
#  ('Burgundy', 121),
#  ('Shoulder', 120),
#  ('Tie', 118),
#  ('Leggings', 117),
#  ('Mesh', 109),
#  ('Piece', 108),
#  ('Mauve', 106),
#  ('Dye', 105),
#  ('All', 103),
#  ('Flare', 102),
#  ('Shorts', 101),
#  ('For', 99),
#  ('Ribbed', 97),
#  ('Taupe', 94),
#  ('Sunglasses', 91),
#  ("Don't", 89),
#  ('Bikini', 89),
#  ('Brown', 88),
#  ('Ivory', 85),
#  ('Jogger', 84),
#  ('Out', 84),
#  ('One', 83),
#  ('Navy', 83),
#  ('Hoodie', 78),
#  ('Sleeve', 78),
#  ('Earrings', 78),
#  ('Necklace', 78),
#  ('Mocha', 77),
#  ('Booty', 76),
#  ('Silver', 76),
#  ('Pink', 76),
#  ('Satin', 73),
#  ('Sequin', 70),
#  ('Sandals', 70),
#  ('Black/White', 69),
#  ('Charcoal', 68),
#  ('Leather', 68),
#  ('Girl', 67),
#  ('Multi', 67),
#  ('With', 66),
#  ('I', 62),
#  ('Cardigan', 60),
#  ('Waist', 59),
#  ('Ankle', 59),
#  ('Cargo', 58),
#  ('Keep', 58),
#  ('Joggers', 57),
#  ('Leopard', 57),
#  ('Back', 56),
#  ('Heeled', 56),
#  ('Long', 55),
#  ('Leg', 55),
#  ('Faux', 54),
#  ('Night', 54),
#  ('Swimsuit', 54),
#  ('Get', 53),
#  ('Black/combo', 53),
#  ('Go', 52),
#  ('Lace', 52),
#  ('Be', 52),
#  ('Way', 52),
#  ('Boyfriend', 52),
#  ('Crop', 52),
#  ('Rust', 51),
#  ('Cover', 50),
#  ('Rose', 50),
#  ('Heel', 50),
#  ('Mustard', 50),
#  ('So', 49),
#  ('Time', 49),
#  ('Classic', 48),
#  ('No', 48),
#  ('Chocolate', 48),
#  ('3', 48),
#  ('Just', 47),
#  ('Heart', 47),
#  ('Neck', 47),
#  ('Down', 47),
#  ('Flat', 47),
#  ('2', 47),
#  ('Super', 45),
#  ('Orange', 45),
#  ('Neon', 44),
#  ('That', 43),
#  ('Clear', 43),
#  ('Hoop', 42),
#  ('Over', 42),
#  ('Not', 42),
#  ('Sandal', 41),
#  ('Around', 40),
#  ('Heels', 40),
#  ('Cut', 40),
#  ('Like', 40),
#  ('Knit', 39),
#  ('Take', 39),
#  ('Tube', 39),
#  ('Oversized', 38),
#  ('Belt', 38),
#  ('Day', 37),
#  ('Waisted', 37),
#  ('Vibe', 37),
#  ('Always', 37),
#  ('Wine', 37),
#  ('Brown/combo', 37),
#  ('Jean', 36),
#  ('Make', 36),
#  ('Chill', 36),
#  ('Boot', 35),
#  ('Stretch', 35),
#  ('Rhinestone', 35),
#  ('Cozy', 35),
#  ('Nova', 34),
#  ('Camo', 34),
#  ('See', 34),
#  ('Good', 34),
#  ('What', 34),
#  ('Anklet', 34),
#  ('Never', 34),
#  ('Shirt', 34),
#  ('Favorite', 33),
#  ('Relaxed', 33),
#  ('Color', 33),
#  ('Mom', 33),
#  ('Got', 32),
#  ('Body', 32),
#  ('Best', 32),
#  ('Ready', 31),
#  ('This', 31),
#  ('Blush', 31),
#  ('At', 31),
#  ('Plaid', 31),
#  ('Life', 31),
#  ("Can't", 30),
#  ('II', 30),
#  ('Green', 30),
#  ('Floral', 30),
#  ('New', 30),
#  ('Sweet', 30),
#  ('Dreams', 30),
#  ('Yellow', 30),
#  ('Season', 29),
#  ('Mid', 29),
#  ('Basic', 29),
#  ('Babe', 29),
#  ('Vibes', 29),
#  ('Straight', 29),
#  ('Look', 29),
#  ('Chain', 29),
#  ('Beach', 28),
#  ('Seamless', 28),
#  ('Terry', 28),
#  ('Ring', 28),
#  ('Mind', 28),
#  ('Hunter', 28),
#  ('Side', 28),
#  ('Stay', 28),
#  ('Game', 27),
#  ('Stole', 27),
#  ("Boyfriend's", 27),
#  ('French', 27),
#  ('Right', 27),
#  ('Baby', 27),
#  ('Stacked', 27),
#  ('Need', 27),
#  ('Days', 26),
#  ('Greatest', 26),
#  ('Tunic', 26),
#  ('Better', 26),
#  ('Come', 26),
#  ('Butterfly', 26),
#  ('Show', 26),
#  ('Latest', 25),
#  ('Khaki', 25),
#  ('Lover', 25),
#  ('Head', 25),
#  ('Let', 25),
#  ('Can', 25),
#  ('Striped', 25),
#  ('Lifting', 24),
#  ('Meet', 24),
#  ('Royal', 24),
#  ('Play', 24),
#  ('Fit', 24),
#  ('Living', 24),
#  ('Tan', 24),
#  ('Bandage', 24),
#  ('Bootie', 24),
#  ('Low', 23),
#  ('Away', 23),
#  ('Talk', 23),
#  ('Active', 23),
#  ('Give', 23),
#  ('Choker', 23),
#  ('Snake', 23),
#  ('Socks', 23),
#  ('Here', 23),
#  ('Casual', 23),
#  ('Feeling', 23),
#  ('Sweatpants', 23),
#  ('Zip', 23),
#  ('Buenos', 22),
#  ('Aires', 22),
#  ('Too', 22),
#  ('Little', 22),
#  ('Twisted', 22),
#  ('Square', 22),
#  ('Velvet', 22),
#  ('Wide', 22),
#  ('Tall', 22),
#  ('Blue/combo', 22),
#  ('Lounge', 22),
#  ('Knot', 21),
#  ('Ruffle', 21),
#  ('Do', 21),
#  ('Soft', 21),
#  ('Double', 21),
#  ('By', 21),
#  ('Bad', 21),
#  ('Tank', 21),
#  ('Call', 21),
#  ('Cross', 21),
#  ('Wild', 21),
#  ('Know', 21),
#  ('Pink/combo', 21),
#  ('From', 20),
#  ('Shaping', 20),
#  ('Wanderlust', 20),
#  ('Through', 20),
#  ('Fleece', 20),
#  ('Free', 20),
#  ('Camel', 20),
#  ('Turtle', 20),
#  ('Hot', 20),
#  ('Than', 20),
#  ("I'm", 20),
#  ('More', 20),
#  ('White/Black', 20),
#  ('Simple', 20),
#  ('Swim', 20),
#  ('Stripe', 20),
#  ("It's", 20),
#  ('Nights', 19),
#  ('But', 19),
#  ('Queen', 19),
#  ('Shine', 19),
#  ('Block', 19),
#  ('Slides', 19),
#  ('Lavender', 19),
#  ('Wrap', 19),
#  ('Everything', 18),
#  ('Button', 18),
#  ('Blazer', 18),
#  ('Print', 18),
#  ('Slit', 18),
#  ('Weekend', 18),
#  ('As', 18),
#  ('Booties', 18),
#  ('About', 18),
#  ('Walk', 18),
#  ('Cream', 18),
#  ('Hooded', 18),
#  ('Glass', 17),
#  ('Curves', 17),
#  ('Sugar', 17),
#  ('Oh', 17),
#  ('Scarf', 17),
#  ('Want', 17),
#  ('Sage', 17),
#  ('Sunsuit', 17),
#  ('Purple', 17),
#  ('Victoria', 16),
#  ('the', 16),
#  ('Dream', 16),
#  ('Boots', 16),
#  ('Happy', 16),
#  ('Party', 16),
#  ('Beauty', 16),
#  ('and', 16),
#  ('Beige', 16),
#  ('PU', 16),
#  ('Cognac', 16),
#  ('Cropped', 16),
#  ('Layered', 16),
#  ('Sculpting', 16),
#  ('Again', 16),
#  ('Summer', 16),
#  ('Natalee', 15),
#  ('Cadet', 15),
#  ('Work', 15),
#  ('Are', 15),
#  ('Moves', 15),
#  ('Grind', 15),
#  ('V', 15),
#  ('Into', 15),
#  ('Moment', 15),
#  ('Comfort', 15),
#  ('Only', 15),
#  ('Halter', 15),
#  ('Tied', 15),
#  ('T', 15),
#  ('Snatched', 15),
#  ('Colorblock', 15),
#  ('White/combo', 15),
#  ('Yes', 14),
#  ('Lifter', 14),
#  ('Slip', 14),
#  ('Hour', 14),
#  ('Slay', 14),
#  ('Knee', 14),
#  ('Chelsea', 14),
#  ('Anything', 14),
#  ('Bodycon', 14),
#  ('Duster', 14),
#  ('Jacket', 14),
#  ('Spot', 14),
#  ('Printed', 14),
#  ('Or', 14),
#  ('Moments', 14),
#  ('Pullover', 14),
#  ('Break', 14),
#  ('Taupe/combo', 14),
#  ('Two', 14),
#  ('Sassy', 14),
#  ('Chic', 14),
#  ('Paparazzi', 14),
#  ('Turtleneck', 14),
#  ("You're", 14),
#  ('First', 13),
#  ('Met', 13),
#  ('Soul', 13),
#  ('Running', 13),
#  ('Strong', 13),
#  ('Twist', 13),
#  ('Street', 13),
#  ('Chase', 13),
#  ('Date', 13),
#  ('Tell', 13),
#  ('Smooth', 13),
#  ('Feels', 13),
#  ("She's", 13),
#  ('Plum', 13),
#  ('Next', 13),
#  ('Slide', 13),
#  ('Tropical', 13),
#  ('Cutting', 13),
#  ('Tee', 13),
#  ('Bracelet', 13),
#  ('Is', 13),
#  ('Green/combo', 13),
#  ('Say', 12),
#  ('Distress', 12),
#  ('Needs', 12),
#  ('Deep', 12),
#  ('Flex', 12),
#  ('of', 12),
#  ('Dare', 12),
#  ('Miss', 12),
#  ('Some', 12),
#  ('Tokyo', 12),
#  ('Everyday', 12),
#  ('Have', 12),
#  ('She', 12),
#  ('Eye', 12),
#  ('Camouflage', 12),
#  ('After', 12),
#  ('Honey', 12),
#  ('True', 12),
#  ('Coming', 12),
#  ('Sun', 12),
#  ('Slouch', 12),
#  ('Easy', 12),
#  ('Now', 12),
#  ('Fun', 12),
#  ('Big', 12),
#  ('Dolphin', 12),
#  ('Crochet', 12),
#  ('Skinnies', 11),
#  ('Indigo', 11),
#  ('Melanie', 11),
#  ('Bag', 11),
#  ('Roll', 11),
#  ('Sexy', 11),
#  ('Run', 11),
#  ('Keeping', 11),
#  ('Vintage', 11),
#  ('Looking', 11),
#  ('Eyes', 11),
#  ('Mint', 11),
#  ('Stone', 11),
#  ('Perfect', 11),
#  ('Real', 11),
#  ('Bell', 11),
#  ("Won't", 11),
#  ('Wedges', 11),
#  ('Combo', 11),
#  ('Mock', 11),
#  ('City', 11),
#  ('Stop', 11),
#  ('Belted', 11),
#  ('Town', 11),
#  ('Touch', 11),
#  ('Mix', 11),
#  ('Zodiac', 11),
#  ('Lose', 10),
#  ('Art', 10),
#  ('Kallan', 10),
#  ('Something', 10),
#  ("Let's", 10),
#  ('We', 10),
#  ('Thing', 10),
#  ('Pump', 10),
#  ('Ripped', 10),
#  ('Stud', 10),
#  ('Watch', 10),
#  ('Metallic', 10),
#  ('Black/Red', 10),
#  ('Marsala', 10),
#  ('Check', 10),
#  ('Drop', 10),
#  ('Her', 10),
#  ('Last', 10),
#  ('Higher', 10),
#  ('Mami', 10),
#  ('Olive/combo', 10),
#  ('Match', 10),
#  ('Smocked', 10),
#  ('Hard', 10),
#  ('Canopy', 9),
#  ('Well', 9),
#  ('Scratch', 9),
#  ("'Em", 9),
#  ('Fool', 9),
#  ('Mulberry', 9),
#  ('Feline', 9),
#  ('His', 9),
#  ('Rhianna', 9),
#  ('If', 9),
#  ('Fall', 9),
#  ('Tennis', 9),
#  ('Caught', 9),
#  ('Fray', 9),
#  ('Start', 9),
#  ('Line', 9),
#  ('Sneaker', 9),
#  ('Studded', 9),
#  ('Please', 9),
#  ('Dusty', 9),
#  ('Pleated', 9),
#  ("What's", 9),
#  ('Strap', 9),
#  ('Girls', 9),
#  ('Feelings', 9),
#  ('Classy', 9),
#  ('Icy', 9),
#  ('Rainbow', 9),
#  ('Care', 9),
#  ('Cute', 9),
#  ('Teal', 9),
#  ('Velour', 9),
#  ('Strappy', 9),
#  ('Fly', 9),
#  ('Brooke', 8),
#  ('Oatmeal', 8),
#  ('Edges', 8),
#  ('Other', 8),
#  ('Bondoc', 8),
#  ('Wave', 8),
#  ('Full', 8),
#  ('Effortless', 8),
#  ('Emma', 8),
#  ('Falls', 8),
#  ('Late', 8),
#  ('Sleek', 8),
#  ('Tara', 8),
#  ('Gotta', 8),
#  ("Payin'", 8),
#  ('Forward', 8),
#  ('Fresh', 8),
#  ('Feel', 8),
#  ('Split', 8),
#  ('Us', 8),
#  ('Fire', 8),
#  ('Ego', 8),
#  ('Round', 8),
#  ('Anne', 8),
#  ('Marie', 8),
#  ('Oil', 8),
#  ('Mean', 8),
#  ('Kiki', 8),
#  ('Euphoria', 8),
#  ('Ponte', 8),
#  ('Cowl', 8),
#  ('Nothing', 8),
#  ('When', 8),
#  ('Wait', 8),
#  ('Status', 8),
#  ('Red/combo', 8),
#  ('Flow', 8),
#  ('Brighter', 8),
#  ('Behavior', 8),
#  ('Simply', 8),
#  ('Bottom', 8),
#  ('Far', 8),
#  ('Vacation', 8),
#  ('Covered', 8),
#  ('Water', 8),
#  ('Them', 8),
#  ('Buckle', 8),
#  ('Things', 8),
#  ('Orange/combo', 8),
#  ('Calling', 8),
#  ('Half', 8),
#  ('Second', 8),
#  ('Wrapped', 8),
#  ('Trouser', 8),
#  ('Coral', 8),
#  ('Doing', 8),
#  ('Move', 8),
#  ('Cool', 8),
#  ('Front', 8),
#  ("90's", 8),
#  ('Business', 8),
#  ('Maui', 8),
#  ('Cutie', 8),
#  ('Slipper', 7),
#  ('Every', 7),
#  ('Ocean', 7),
#  ('Kim', 7),
#  ('Soothe', 7),
#  ('Tight', 7),
#  ('Much', 7),
#  ('Sunshine', 7),
#  ('Jacklyn', 7),
#  ('Killing', 7),
#  ('Boys', 7),
#  ('Pretty', 7),
#  ('Fast', 7),
#  ('Shanghai', 7),
#  ('Katie', 7),
#  ('Flame', 7),
#  ('Anna', 7),
#  ('Made', 7),
#  ('Frisky', 7),
#  ('Sliders', 7),
#  ('Eva', 7),
#  ('Curvy', 7),
#  ('Boy', 7),
#  ('Net', 7),
#  ('Toe', 7),
#  ('Beyond', 7),
#  ('Flowers', 7),
#  ('Lounger', 7),
#  ('Giving', 7),
#  ('Affair', 7),
#  ('Ever', 7),
#  ('Special', 7),
#  ('Rest', 7),
#  ('Wish', 7),
#  ('An', 7),
#  ('Nice', 7),
#  ('Solid', 7),
#  ('There', 7),
#  ('Falling', 7),
#  ('Matching', 7),
#  ('Essential', 7),
#  ('Natural', 7),
#  ('Bae', 7),
#  ('Secrets', 7),
#  ('Enough', 7),
#  ('Destroyed', 7),
#  ('Moto', 7),
#  ('Tonight', 7),
#  ('Him', 7),
#  ('Corners', 7),
#  ('Link', 7),
#  ('Throw', 7),
#  ('Forever', 7),
#  ('Under', 7),
#  ("That's", 7),
#  ('Attention', 7),
#  ('Kiss', 7),
#  ('Man', 7),
#  ('Stunning', 7),
#  ('Blame', 7),
#  ('Ways', 7),
#  ('Corset', 7),
#  ('Rock', 7),
#  ('Glitter', 7),
#  ('Crossed', 7),
#  ('Overalls', 7),
#  ('Another', 7),
#  ('Step', 7),
#  ('Fierce', 7),
#  ('Adventure', 7),
#  ('Island', 7),
#  ('Modern', 7),
#  ('Strings', 7),
#  ('Lined', 7),
#  ('Coverup', 7),
#  ('Downtown', 7),
#  ('Choice', 7),
#  ('Sheer', 7),
#  ('Cutout', 7),
#  ('Animal', 7),
#  ('Ties', 7),
#  ('Together', 7),
#  ('Sweatshirt', 7),
#  ('Fuchsia', 7),
#  ('Crew', 7),
#  ('Glistening', 6),
#  ('Almost', 6),
#  ('Drive', 6),
#  ('Pick', 6),
#  ('Uncomplicated', 6),
#  ('Played', 6),
#  ('Needing', 6),
#  ('Our', 6),
#  ('Hit', 6),
#  ('Thigh', 6),
#  ('Luxe', 6),
#  ('Cami', 6),
#  ('Extra', 6),
#  ('Mile', 6),
#  ('Nita', 6),
#  ('Shake', 6),
#  ('Vinyl', 6),
#  ('Drama', 6),
#  ('Edge', 6),
#  ('Midnight', 6),
#  ('Louise', 6),
#  ('Hearts', 6),
#  ('Pro', 6),
#  ('Crossover', 6),
#  ('Trouble', 6),
#  ('Applause', 6),
#  ('Shaped', 6),
#  ('Story', 6),
#  ('Trend', 6),
#  ('Mineral', 6),
#  ('Even', 6),
#  ('Dinner', 6),
#  ('Type', 6),
#  ('Carpenter', 6),
#  ('Puppy', 6),
#  ('Black/Brown', 6),
#  ('Heat', 6),
#  ('Ride', 6),
#  ('Attraction', 6),
#  ('Analissa', 6),
#  ('Sparkle', 6),
#  ('Breaking', 6),
#  ('Hold', 6),
#  ('Occasion', 6),
#  ('Smock', 6),
#  ('Ariana', 6),
#  ('Waffle', 6),
#  ('Slash', 6),
#  ('Graphic', 6),
#  ('Times', 6),
#  ('Cold', 6),
#  ('HeatherGrey', 6),
#  ('in', 6),
#  ('Rib', 6),
#  ('Baddie', 6),
#  ('Begin', 6),
#  ('Bright', 6),
#  ('Lucky', 6),
#  ('Culture', 6),
#  ('Navy/combo', 6),
#  ('Angel', 6),
#  ("Feelin'", 6),
#  ('Overall', 6),
#  ('Close', 6),
#  ('Dull', 6),
#  ('Going', 6),
#  ('Finish', 6),
#  ('Breeze', 6),
#  ('Snakeskin', 6),
#  ('PVC', 6),
#  ('Tiny', 6),
#  ('Dreaming', 6),
#  ('Think', 6),
#  ('Fuzzy', 6),
#  ('Pendant', 6),
#  ('Name', 6),
#  ('Such', 6),
#  ('Sleeveless', 6),
#  ('Pearl', 6),
#  ('Tortoise', 6),
#  ('Money', 6),
#  ('Secret', 6),
#  ('Mama', 5),
#  ('Believe', 5),
#  ('Spree', 5),
#  ('Hug', 5),
#  ('it', 5),
#  ('Tummy', 5),
#  ('Jane', 5),
#  ('Camp', 5),
#  ('Beverly', 5),
#  ('Valentina', 5),
#  ('Magic', 5),
#  ('Kora', 5),
#  ('Class', 5),
#  ('Shortie', 5),
#  ('Bye', 5),
#  ('Tori', 5),
#  ('Frenzy', 5),
#  ('Holy', 5),
#  ('Holder', 5),
#  ('Between', 5),
#  ('Earring', 5),
#  ('Sunday', 5),
#  ('Kind', 5),
#  ('Magenta', 5),
#  ('Sight', 5),
#  ('Black/Black', 5),
#  ('Seeing', 5),
#  ('Own', 5),
#  ('Bold', 5),
#  ('Wrong', 5),
#  ('Spotless', 5),
#  ('Lean', 5),
#  ('Die', 5),
#  ('Schedule', 5),
#  ('Daze', 5),
#  ('Different', 5),
#  ('Said', 5),
#  ('White/Pink', 5),
#  ('Switch', 5),
#  ('Gears', 5),
#  ('Grey/combo', 5),
#  ('Jodie', 5),
#  ('Matter', 5),
#  ('Focus', 5),
#  ('Longer', 5),
#  ('Catch', 5),
#  ('Chasing', 5),
#  ('Arms', 5),
#  ('Flying', 5),
#  ('Zoe', 5),
#  ('Pocket', 5),
#  ('Skort', 5),
#  ('Melinda', 5),
#  ('Facts', 5),
#  ('Chicago', 5),
#  ('Morning', 5),
#  ('Crazy', 5),
#  ('Somewhere', 5),
#  ('Gone', 5),
#  ('Trip', 5),
#  ('Hem', 5),
#  ('Desert', 5),
#  ('Later', 5),
#  ('Black/Combo', 5),
#  ('Electric', 5),
#  ('Sports', 5),
#  ('Cat', 5),
#  ('Gypsy', 5),
#  ('Ivory/combo', 5),
#  ('Ahead', 5),
#  ('Sea', 5),
#  ('Dying', 5),
#  ('Shield', 5),
#  ('Walking', 5),
#  ('Cable', 5),
#  ('Sweetie', 5),
#  ('Mine', 5),
#  ('Gown', 5),
#  ('Cuddle', 5),
#  ('Star', 5),
#  ('Patchwork', 5),
#  ('Yet', 5),
#  ('Bring', 5),
#  ('Same', 5),
#  ('Trust', 5),
#  ('Forget', 5),
#  ('Kick', 5),
#  ('Middle', 5),
#  ('Black/Grey', 5),
#  ('Myself', 5),
#  ('Desire', 5),
#  ('Had', 5),
#  ('Stripes', 5),
#  ('Champ', 5),
#  ('White/Combo', 5),
#  ('Looks', 5),
#  ('Fame', 5),
#  ('Hide', 5),
#  ('Trio', 5),
#  ('Leave', 5),
#  ('Still', 5),
#  ('Mauve/combo', 5),
#  ('Dangerous', 5),
#  ('Beautiful', 5),
#  ('Black/Gold', 5),
#  ('Ruche', 5),
#  ('Gold/Brown', 5),
#  ('Triangle', 5),
#  ('Edition', 5),
#  ('Fantasy', 5),
#  ('Latex', 5),
#  ('Skies', 5),
#  ('School', 5),
#  ('Must', 5),
#  ('Burgundy/combo', 5),
#  ('Fur', 5),
#  ('Leena', 5),
#  ('Vacay', 5),
#  ('Softie', 5),
#  ('Snap', 5),
#  ('Santorini', 5),
#  ('Embellished', 5),
#  ('Revenge', 5),
#  ('Sport', 5),
#  ('Black/Smoke', 5),
#  ('Waiting', 5),
#  ('Sherpa', 5),
#  ('Supernatural', 4),
#  ('Bum', 4),
#  ('Since', 4),
#  ('Marilyn', 4),
#  ('Lola', 4),
#  ('Daily', 4),
#  ('Perfectly', 4),
#  ('Kindly', 4),
#  ('Tuck', 4),
#  ('Sammie', 4),
#  ('Remedy', 4),
#  ('Plain', 4),
#  ('Maura', 4),
#  ('Fever', 4),
#  ('Everywhere', 4),
#  ('Henley', 4),
#  ('Devil', 4),
#  ('Liliana', 4),
#  ('Hills', 4),
#  ('Grown', 4),
#  ('Plot', 4),
#  ('Sex', 4),
#  ('Ultra', 4),
#  ('Wifey', 4),
#  ('Whole', 4),
#  ('Lotta', 4),
#  ('Olivia', 4),
#  ('Club', 4),
#  ('Operator', 4),
#  ('Miles', 4),
#  ('Alone', 4),
#  ("I'll", 4),
#  ('Aviator', 4),
#  ('Carla', 4),
#  ('Softly', 4),
#  ('Tubular', 4),
#  ('Brown/Combo', 4),
#  ('Hong', 4),
#  ('Kong', 4),
#  ('Level', 4),
#  ('Sigh', 4),
#  ('Precious', 4),
#  ('Very', 4),
#  ('Bling', 4),
#  ('List', 4),
#  ('Bar', 4),
#  ('Did', 4),
#  ('Number', 4),
#  ('Grace', 4),
#  ('Fuck', 4),
#  ('Olive/Combo', 4),
#  ('Mess', 4),
#  ('Found', 4),
#  ('Flip', 4),
#  ('Perfection', 4),
#  ('Hearted', 4),
#  ('Bounce', 4),
#  ('Birthday', 4),
#  ('Rosie', 4),
#  ('Blessings', 4),
#  ('Adorn', 4),
#  ('Center', 4),
#  ('Beret', 4),
#  ('Three', 4),
#  ('Glow', 4),
#  ('Feelin', 4),
#  ('Dragon', 4),
#  ('Chilled', 4),
#  ('Boho', 4),
#  ('Task', 4),
#  ('Thinking', 4),
#  ('Ancient', 4),
#  ('Rome', 4),
#  ('Needy', 4),
#  ('Dana', 4),
#  ('Diamonds', 4),
#  ('Who', 4),
#  ('Lime', 4),
#  ('Power', 4),
#  ('Ex', 4),
#  ('Janelle', 4),
#  ('Winner', 4),
#  ('Lyla', 4),
#  ('Jazmin', 4),
#  ('Headband', 4),
#  ('Chains', 4),
#  ('Kelly', 4),
#  ('Diamond', 4),
#  ('Mode', 4),
#  ('Point', 4),
#  ('Direction', 4),
#  ('Across', 4),
#  ('Places', 4),
#  ('Complete', 4),
#  ('Magnetic', 4),
#  ('Romance', 4),
#  ('Remember', 4),
#  ('Any', 4),
#  ('Puff', 4),
#  ('Talking', 4),
#  ('Blooming', 4),
#  ('Style', 4),
#  ('Vitamin', 4),
#  ('Green/Combo', 4),
#  ('Taking', 4),
#  ('Sass', 4),
#  ('Yellow/combo', 4),
#  ('Lash', 4),
#  ('Butterflies', 4),
#  ('Common', 4),
#  ('Pad', 4),
#  ('Stare', 4),
#  ('Spice', 4),
#  ('Dainty', 4),
#  ('Maribel', 4),
#  ('Rhonda', 4),
#  ('How', 4),
#  ('Ariah', 4),
#  ('Manners', 4),
#  ('Attitude', 4),
#  ('Chills', 4),
#  ('Miami', 4),
#  ('House', 4),
#  ('Bronze', 4),
#  ('Thought', 4),
#  ('Case', 4),
#  ('Notch', 4),
#  ('Faced', 4),
#  ('Purple/combo', 4),
#  ('Slim', 4),
#  ...]
