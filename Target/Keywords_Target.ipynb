# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
file_path = r"C:\Users\Braydon\Desktop\Shein_Data\Pivot_Data\Target\Target_Data_Output.csv"

# %%
df = pd.read_csv(file_path)

# %%
df
# Out:
#                                              Cloth_Desc  Price
# 0      High-Waisted Classic Leggings - Wild Fable Black   7.00
# 1                            Tiny Tank Top - Wild Fable   4.00
# 2     90 Degree by Reflex - Women's Soft Comfy Loung...  19.99
# 3     Tonal Shamrocks St. Patrick's Day Crew Socks -...   4.00
# 4               Short Sleeve Casual T-Shirt - A New Day   4.80
# ...                                                 ...    ...
# 1204  U-Neck Multi-Way Bralette Bikini Top - Wild Fa...  18.00
# 1205  Tie-Front Dolman Short Sleeve T-Shirt - Ava & Viv  14.40
# 1206  Super-High Rise Slim Straight Jeans - Wild Fab...  25.00
# 1207   Pucker Texture Square Neck Bikini Top - Kona Sol  23.00
# 1208  Shades of Beauty Short Sleeve Graphic T-Shirt ...  10.39
#
# [1209 rows x 2 columns]

# %%
cloth_word_lst = []

for item in df['Cloth_Desc']:
    item = item.split()
    for thing in item:
        cloth_word_lst.append(thing)

# %%
cloth_word_count = Counter(cloth_word_lst)

# %%
cloth_word_count
# Out:
# Counter({'High-Waisted': 12,
#          'Classic': 6,
#          'Leggings': 38,
#          '-': 1121,
#          'Wild': 157,
#          'Fable': 157,
#          'Black': 101,
#          'Tiny': 2,
#          'Tank': 50,
#          'Top': 124,
#          '90': 1,
#          'Degree': 1,
#          'by': 30,
#          'Reflex': 1,
#          "Women's": 181,
#          'Soft': 37,
#          'Comfy': 1,
#          'Lounge': 17,
#          'Shorts': 49,
#          'with': 27,
#          'Pockets': 4,
#          'Tonal': 1,
#          'Shamrocks': 3,
#          'St.': 25,
#          "Patrick's": 24,
#          'Day': 186,
#          'Crew': 47,
#          'Socks': 304,
#          'Dark': 6,
#          'Green': 23,
#          '4-10': 221,
#          'Short': 112,
#          'Sleeve': 167,
#          'Casual': 6,
#          'T-Shirt': 107,
#          'A': 157,
#          'New': 156,
#          'Plush': 2,
#          'Cotton': 50,
#          'Unisex': 1,
#          'Adult': 1,
#          'Bathrobe': 2,
#          'Blue': 35,
#          'Nile': 1,
#          'Mills': 1,
#          'Gradient': 1,
#          'Shamrock': 11,
#          'Low': 96,
#          'Cut': 108,
#          'Ribbed': 51,
#          'Alexander': 3,
#          'del': 2,
#          'Rossa': 3,
#          'Raglan': 2,
#          'Sleep': 8,
#          'Shirt': 11,
#          'Pockets,': 1,
#          'Long': 43,
#          'Nightshirt,': 2,
#          'Lightweight': 30,
#          'Nightgown': 2,
#          'Extended': 23,
#          'Shoulder': 12,
#          'Shirt,': 1,
#          'Relaxed': 11,
#          'Fit': 44,
#          'Collared': 1,
#          'Button-Down': 9,
#          'Universal': 77,
#          'Thread': 77,
#          'Fashion': 9,
#          'Forms': 8,
#          'Reusable': 4,
#          'Silicone': 1,
#          'Gel': 2,
#          'Petals': 4,
#          'Slim': 29,
#          'Square': 11,
#          'Neck': 23,
#          'Elbow': 5,
#          'Boxy': 7,
#          'Cropped': 26,
#          'V-Neck': 29,
#          'Dress': 49,
#          'Tape': 1,
#          'With': 1,
#          'Dispenser': 1,
#          'Laser': 7,
#          'Thong': 14,
#          'Auden': 92,
#          'Doxie': 1,
#          'Multipattern': 4,
#          '6pk': 130,
#          'Cheeky': 44,
#          'Underwear': 44,
#          'Cami': 13,
#          'Irish': 2,
#          'Pug': 1,
#          'Guinea': 1,
#          'Pig': 3,
#          'Xhilaration': 84,
#          'Pink': 11,
#          'One': 34,
#          'Size': 33,
#          'Stretch': 9,
#          'Woven': 7,
#          'Tapered': 5,
#          'Cargo': 3,
#          'Pants': 57,
#          'All': 122,
#          'in': 102,
#          'Motion': 100,
#          'High-Rise': 61,
#          'Ankle': 45,
#          'Pull-On': 12,
#          'Del': 1,
#          'Warm': 2,
#          'Winter': 1,
#          'Robe,': 1,
#          'Fleece': 18,
#          'Full': 9,
#          'Length': 1,
#          'Lucky': 4,
#          'Llama': 4,
#          'Hipster': 24,
#          'Smocked': 8,
#          'Waist': 27,
#          'Side': 12,
#          'Slit': 4,
#          'Cover': 18,
#          'Up': 20,
#          'Kona': 46,
#          'Sol': 46,
#          'Bikini': 124,
#          'Sparkly': 2,
#          'Micro': 7,
#          "'Top": 1,
#          'of': 27,
#          'the': 29,
#          'Meowning': 1,
#          'to': 1,
#          "Ya'": 1,
#          'Heather': 22,
#          'Gray': 34,
#          'Beautifully': 21,
#          'Jogger': 12,
#          'Stars': 48,
#          'Above': 48,
#          'Oversized': 13,
#          'Muscle': 2,
#          'Seamless': 53,
#          'Flare': 15,
#          'Rainbow': 5,
#          'Fuzzy': 3,
#          'Clouds': 1,
#          'Oatmeal': 5,
#          'Hanes': 67,
#          'Premium': 37,
#          '6': 8,
#          'Pack': 10,
#          'Cushioned': 49,
#          '5-9': 20,
#          'Allover': 1,
#          'Lace': 23,
#          'Bonded': 5,
#          'Perfectly': 6,
#          'Cozy': 34,
#          'Comfort': 15,
#          'Button-Up': 1,
#          'Shirtdress': 3,
#          'Chenille': 1,
#          'Robe': 7,
#          'White': 28,
#          'Pointelle': 3,
#          'Pullover': 12,
#          'Sweater': 17,
#          'Taper': 4,
#          'Active': 16,
#          'Marled': 5,
#          '2pk': 30,
#          "'Feelin'": 1,
#          "Clucky'": 1,
#          'Navy/Green': 3,
#          'Puff': 12,
#          'Striped': 28,
#          'Pizza': 1,
#          'Solid': 1,
#          'Knee': 9,
#          'High': 64,
#          'Linen': 8,
#          'Short-Sleeve': 3,
#          'Shrunken': 3,
#          'Slouch': 1,
#          'Mid-Rise': 18,
#          'Wide': 10,
#          'Leg': 32,
#          'Sleeveless': 16,
#          'Knit': 13,
#          'Bodycon': 4,
#          '10pk': 27,
#          'Midi': 5,
#          'A-Line': 9,
#          'Slip': 2,
#          'Skirt': 14,
#          'Nursing': 8,
#          'Bra': 42,
#          'Trim': 5,
#          'Rib': 8,
#          'Triangle': 18,
#          'Bralette': 39,
#          'Colsie': 30,
#          'Out': 11,
#          'Front': 19,
#          'Placket': 1,
#          'Boy': 5,
#          'Farmer': 1,
#          'Chicken': 1,
#          'Denim': 8,
#          'Sloth': 5,
#          'Orange': 11,
#          'Cow': 4,
#          'Figure': 1,
#          'Adhesive': 5,
#          'Strapless': 6,
#          'Backless': 4,
#          'Clear': 1,
#          'Rainy': 2,
#          'Charcoal': 9,
#          'Cat': 7,
#          'Faces': 1,
#          'Peach': 5,
#          'Hamburger': 1,
#          'Light': 24,
#          'Fitted': 6,
#          'Faux': 6,
#          'Fur': 1,
#          'Slipper': 7,
#          'Gauze': 5,
#          'Dr.': 1,
#          'Aqua': 18,
#          'Risque': 4,
#          'No': 64,
#          'Show': 63,
#          'Disposable': 2,
#          'Nipple': 4,
#          'Covers,': 4,
#          '40petals': 2,
#          'Ultra': 22,
#          'Flex': 9,
#          '3pk': 49,
#          'Waistband': 7,
#          'Maxi': 4,
#          'Duster': 2,
#          'Hearts': 1,
#          'Heather/Green': 1,
#          'Brushed': 10,
#          'Sculpt': 10,
#          'Camping': 2,
#          'Hedgehogs': 1,
#          'Kindness': 1,
#          'Graphic': 66,
#          'Floral': 30,
#          'and': 20,
#          'Pajama': 25,
#          'Set': 11,
#          '8-12': 21,
#          'Notch': 9,
#          'Collar': 9,
#          'Strawberry': 1,
#          'Shortcake': 1,
#          'Black/White/Gray': 3,
#          'Lingerie': 1,
#          'Spaghetti': 2,
#          'Strap': 7,
#          'Bodysuit': 11,
#          'Tanga': 1,
#          'Nirvana': 1,
#          'Reversible': 3,
#          'String': 3,
#          'Super-High': 12,
#          'Rise': 12,
#          'Distressed': 5,
#          'Straight': 17,
#          'Jeans': 30,
#          'Medium': 17,
#          'Wash': 13,
#          'Open': 3,
#          'Cardigan': 6,
#          'Party': 1,
#          'Dino': 2,
#          'Cream': 6,
#          'Utility': 5,
#          'Open-Front': 1,
#          'Peds': 26,
#          'Unseen': 2,
#          'Liner': 60,
#          '5-10': 19,
#          'Cable': 2,
#          'Pull': 2,
#          'Over': 8,
#          'Snorkeling': 1,
#          'ASSETS': 8,
#          'SPANX': 8,
#          'High-Waist': 5,
#          'Shaping': 3,
#          'Tights': 28,
#          'Spring': 2,
#          'Blazer': 3,
#          'Workout': 1,
#          'Hamsters': 1,
#          'Seamed': 2,
#          'Jumpsuit': 3,
#          'Briefs': 24,
#          'Hello': 1,
#          'Kitty': 1,
#          'Brown': 8,
#          'Baby': 4,
#          'Bee': 2,
#          'Navy': 7,
#          'JoyLab': 6,
#          'Fruit': 26,
#          'Snails': 1,
#          'Sweatshirt': 42,
#          'Original': 1,
#          'Support': 21,
#          'Sports': 16,
#          'Sheer': 16,
#          'Rose': 34,
#          'Thigh': 7,
#          'Highs': 6,
#          'Assorted': 35,
#          'Colors': 59,
#          'House': 1,
#          'Plant': 1,
#          'Olive': 1,
#          'Longline': 11,
#          'Waffle': 3,
#          'Bell': 2,
#          'Satin': 17,
#          'Fly': 1,
#          'Away': 1,
#          'Skater': 3,
#          'Essential': 7,
#          'Fern': 1,
#          'Cushion': 6,
#          'Heel': 6,
#          'Beige': 7,
#          'Nude': 5,
#          'Contour': 7,
#          'Power': 7,
#          'Corset': 5,
#          'Matte': 1,
#          'Ombre': 3,
#          'show': 1,
#          'Athletic': 71,
#          'Mesh': 23,
#          'Maternity': 30,
#          'Isabel': 30,
#          'Ingrid': 15,
#          '&': 77,
#          'Mixed': 3,
#          'Pattern': 3,
#          'Black/Green': 2,
#          'Midline': 4,
#          'Panda': 4,
#          'DJ': 1,
#          'Periwinkle': 2,
#          'NightGown': 6,
#          'Low-Rise': 4,
#          'Be': 1,
#          'Kind': 2,
#          'Festival': 1,
#          'Stripe': 3,
#          'Pandas': 1,
#          'Pool': 1,
#          'Floaty': 1,
#          "'Easy": 1,
#          "Beezy'": 1,
#          'Zip-Front': 1,
#          'Jacket': 8,
#          'Skinny': 11,
#          'Tie-Dye': 6,
#          'Blue/Gray': 1,
#          'Ruched': 10,
#          'Shirred': 9,
#          'Bottom': 55,
#          '"Drop': 1,
#          'It': 3,
#          'Like': 1,
#          'Sloth"': 1,
#          'Tiered': 7,
#          'Chiffon': 2,
#          'Non-Adhesive': 1,
#          'Animal': 6,
#          'Print': 39,
#          'Multitasking': 1,
#          'Octopus': 1,
#          '"Meowning': 1,
#          'Coffee"': 1,
#          "'Stay": 1,
#          "Golden'": 1,
#          'Dog': 2,
#          'Polka': 2,
#          'Dots': 1,
#          'Blouse': 8,
#          'The': 11,
#          'Rolling': 4,
#          'Stones': 4,
#          'Brami': 4,
#          'Coverage': 19,
#          'Pantyhose': 5,
#          'Mary': 2,
#          'Jane': 2,
#          'Fold': 2,
#          'Cuff': 2,
#          'Budweiser': 1,
#          'Layering': 2,
#          'Space': 1,
#          'Dreaming': 1,
#          'Llamas': 1,
#          'Plisse': 3,
#          'Babydoll': 3,
#          'Zip-Up': 2,
#          'Hoodie': 4,
#          'Foldover': 1,
#          'Boxer': 4,
#          'Simply': 5,
#          'Cool': 10,
#          'Leprechaun': 1,
#          'Gnome': 1,
#          'Pear': 1,
#          'Loom': 23,
#          'Sheep': 1,
#          '3"': 2,
#          'French': 11,
#          'Terry': 11,
#          '3.5"': 2,
#          'Vacation': 1,
#          'Bear': 1,
#          'White/Black/Pink': 1,
#          'Boyfriend': 5,
#          'Wrap': 4,
#          "Schitt's": 1,
#          'Creek': 1,
#          'Apothecary': 1,
#          'Plus': 7,
#          'Scoop': 15,
#          'Ava': 13,
#          'Viv': 13,
#          '8pk': 1,
#          'White/Green': 3,
#          'Basic': 2,
#          'Fishnet': 5,
#          'Day&#153': 1,
#          'Sanrio': 2,
#          'My': 3,
#          'Melody': 1,
#          'History': 6,
#          'Month': 6,
#          'Beautiful,': 1,
#          'Black,': 3,
#          'Proud': 1,
#          'Balloon': 5,
#          'Off': 1,
#          'Racerback': 10,
#          "'Incorgnito'": 1,
#          'Perfect': 9,
#          'Ivory': 5,
#          'Dolphin': 1,
#          'Hanes®': 3,
#          'Silky': 1,
#          'Control': 13,
#          'Hooded': 3,
#          'Run': 2,
#          'Tummy': 4,
#          'Waisted': 5,
#          'X-Side': 1,
#          'Sport': 9,
#          'Swim': 9,
#          'Amazing': 1,
#          'Colorpop': 1,
#          'Music': 1,
#          'City': 1,
#          '4pk': 29,
#          'Bike': 7,
#          'Farm': 3,
#          'Barn': 1,
#          'Blue/Gray/Pink': 2,
#          'Core': 3,
#          '5"': 2,
#          'Def': 1,
#          'Leppard': 1,
#          'Logo': 3,
#          'Bold,': 1,
#          'Bougie': 1,
#          'Bronze': 1,
#          '20D': 7,
#          'Opaque': 8,
#          'Dot': 2,
#          "Patricks'": 1,
#          'Tupac': 1,
#          'Mini': 3,
#          'Black/White': 4,
#          'Kick': 3,
#          'Science': 1,
#          'Hamster': 2,
#          'Sushi': 1,
#          'Corgi': 2,
#          'Blue/White/Gray': 2,
#          'Ruffle': 12,
#          'Tie-Front': 8,
#          'Critters': 3,
#          'Umbrellas': 1,
#          'Minnie': 4,
#          'Large': 1,
#          'Piece': 24,
#          'Swimsuit': 25,
#          'Shade': 31,
#          'Shore': 31,
#          'Convertible': 2,
#          'Super': 8,
#          'Spotted': 2,
#          'Cats': 3,
#          'Yarn': 1,
#          'Gummy': 1,
#          'Bears': 3,
#          'Boyshorts': 2,
#          'Fall': 1,
#          'Berries': 1,
#          'Sweatpants': 1,
#          'Fluid': 2,
#          'Sublime': 2,
#          'Simplicity': 4,
#          'Capri': 1,
#          '20"': 1,
#          'Mock': 1,
#          'Turtleneck': 1,
#          '-Stars': 1,
#          'Slub': 2,
#          '90s': 2,
#          'Icons': 2,
#          'White/Heather': 2,
#          'Gray/Black': 1,
#          'Coffee': 4,
#          'Lattes': 1,
#          'Black/Cream/Pink': 1,
#          'Breast': 1,
#          'Handkerchief': 1,
#          'Hem': 2,
#          'Supplex': 1,
#          'Harry': 3,
#          'Potter': 3,
#          'Frenchie': 1,
#          'Fry': 1,
#          '7/8': 2,
#          'Legging': 2,
#          'Polyester': 1,
#          'Curvy': 3,
#          'Shelf': 1,
#          'Looney': 1,
#          'Tunes': 1,
#          "That's": 1,
#          'Folks': 1,
#          'On': 1,
#          'Grippers': 5,
#          'Sarong': 3,
#          'Back': 8,
#          'Boyshort': 1,
#          'Star': 4,
#          'Wars:': 2,
#          'Mandalorian': 3,
#          'Child': 1,
#          'Microsuede': 2,
#          '7-9.5': 1,
#          'Gilmore': 1,
#          'Girls': 1,
#          "Luke's": 1,
#          'Simple': 1,
#          'Wishes': 1,
#          'Hands': 1,
#          'Free': 1,
#          'Pumping': 1,
#          'Adjustable': 6,
#          'XS-L': 1,
#          'Outerspace': 1,
#          'Stickies': 2,
#          '2Cover(s)': 2,
#          'Gray/White/Black': 1,
#          'Removable': 1,
#          'Pad': 1,
#          'Microfiber': 4,
#          'Drapey': 1,
#          'Wyoming': 1,
#          'Performance': 12,
#          'Daisy': 1,
#          'Days': 1,
#          'Week': 1,
#          'Snacks': 1,
#          'Two-Tone': 1,
#          'Plunge': 9,
#          'V-Wire': 1,
#          'St': 1,
#          'Gudetama': 1,
#          'Yellow': 3,
#          'Breakfast': 2,
#          'Cream/Gray/Olive': 1,
#          'Yoga': 1,
#          'Voice,': 1,
#          '50D': 4,
#          '3pc': 1,
#          'Colorful': 2,
#          'Navy/Pink': 1,
#          'Ballet': 1,
#          'Coolmax': 2,
#          'May': 35,
#          'Vary': 35,
#          'Comfortsoft': 1,
#          'Mid-Thigh': 2,
#          'Shark': 1,
#          'Sunglasses': 1,
#          'Knox': 31,
#          'Hedgehog': 2,
#          'White/Pink/Heather': 1,
#          'Pro': 16,
#          'FX': 4,
#          'Lilo': 4,
#          'Stitch': 7,
#          'Flintstones': 1,
#          'Burgundy': 1,
#          'Eyelet': 6,
#          'Drinking': 1,
#          'Detail': 6,
#          'Green®': 9,
#          'So': 4,
#          'Unlined': 4,
#          'Tassle': 1,
#          'Crochet': 8,
#          'Guns': 2,
#          "n'": 1,
#          'Roses': 2,
#          'Accents': 6,
#          'Tab': 18,
#          '3/4': 8,
#          'Drape': 2,
#          'Leopard': 2,
#          'Strappy': 5,
#          'Exercise': 1,
#          'Camaro': 1,
#          'Red': 3,
#          '100%': 3,
#          'Dinosaur': 1,
#          'Navy/White/Pink': 1,
#          'Dinosaurs': 1,
#          'Stripes': 1,
#          'Pink/Blue/Purple': 1,
#          'Yosemite': 1,
#          'High-Neck': 1,
#          'Belly': 3,
#          'Button-Front': 3,
#          'Boilersuit': 1,
#          'Crewneck': 8,
#          'Side-Tie': 11,
#          'Hi-Cut': 5,
#          'Nylon': 2,
#          'Abstract': 2,
#          'Tropical': 7,
#          'Avocado': 2,
#          'Toast': 1,
#          'Extra': 6,
#          'Easter': 2,
#          'Bunny': 2,
#          'Ears': 2,
#          'Spritz': 2,
#          'Textured': 13,
#          'Ring': 3,
#          'Bow': 2,
#          'Corded': 2,
#          'Racer': 1,
#          'Fine': 4,
#          'Gauge': 3,
#          'Pucker': 6,
#          'Tube': 1,
#          'Bliss': 1,
#          'Lightly': 4,
#          'Lined': 4,
#          'Wirefree': 4,
#          'True': 2,
#          'Co.': 1,
#          'Everybody': 1,
#          'Ponte': 3,
#          'Hair': 1,
#          'Pic': 1,
#          'Purple': 7,
#          'Wars': 2,
#          'Gray/Pink': 2,
#          'Memory': 1,
#          'Underwire': 5,
#          'Blue/Pink/Gray': 2,
#          'Lace-Up': 9,
#          'briefs': 4,
#          'Breathable': 7,
#          'Micro-Mesh': 3,
#          'Gray/Blue/Yellow': 1,
#          'Retro': 3,
#          'Airy': 1,
#          '5pk': 2,
#          'Pindot': 1,
#          'Modal': 2,
#          'Citrus': 1,
#          'Fruits': 1,
#          'MTV': 1,
#          'Tactel': 1,
#          'Mule': 1,
#          'Gray/Pink/Blue': 1,
#          'Blackout': 2,
#          'Liquid': 1,
#          'Black/White/Heather': 1,
#          'Color': 2,
#          'Sailor': 3,
#          'Moon': 3,
#          'Rib-Knit': 1,
#          'Winnie': 1,
#          'Pooh': 1,
#          'Side-Tab': 2,
#          'Crop': 3,
#          'Side-Slit': 1,
#          'Jockey': 9,
#          'Generation': 9,
#          'Natural': 1,
#          'Beauty': 2,
#          'Hi-Cuts': 1,
#          'Crossover': 4,
#          'Tankini': 10,
#          'Signature': 1,
#          'Smooth': 1,
#          'Mario': 1,
#          'Disney': 4,
#          'Pixar': 1,
#          'Tinkerbell': 1,
#          'Tan': 2,
#          'Forest': 1,
#          'Sun': 1,
#          '10-12': 1,
#          'Joe': 1,
#          'Snoopy': 1,
#          'Mom': 4,
#          'Bermuda': 1,
#          'Elastic': 1,
#          'Skirtini': 2,
#          'Halter': 4,
#          'Argyle': 1,
#          'Blend': 1,
#          'Merino': 1,
#          'Wool': 1,
#          'XL': 1,
#          'Butterfly': 2,
#          'Charm': 1,
#          'Knot': 1,
#          'Tie': 4,
#          'Tunic': 4,
#          'Trucker': 1,
#          'Mickey': 2,
#          'Mouse': 4,
#          'White/Red/Blue': 1,
#          'Texas': 1,
#          '+': 1,
#          'Destructed': 2,
#          'Balconette': 1,
#          'Traction': 1,
#          'Thermal': 3,
#          'Sweetheart': 1,
#          'Spacedye': 2,
#          'Romper': 2,
#          'Viney': 1,
#          'Toe': 5,
#          'Taco': 1,
#          'Mint/Blue/White': 1,
#          'Floyd': 1,
#          'Pleated': 1,
#          'Skorts': 1,
#          'Loom®': 1,
#          'Fx': 1,
#          'White/Purple': 1,
#          '4"': 1,
#          '7"': 1,
#          'Playful': 1,
#          'Gray/White': 2,
#          'Keyhole': 1,
#          'Nightmare': 2,
#          'Before': 2,
#          'Christmas': 2,
#          'Care': 2,
#          'Seamfree': 2,
#          'Angled': 1,
#          'Honey': 1,
#          'Patterns': 2,
#          'Quarter': 1,
#          'Zip': 2,
#          'Twist-Front': 3,
#          'Watermelon': 1,
#          'Puppy': 1,
#          'Heather/Heather': 1,
#          'Rosie': 1,
#          'Houses': 1,
#          'Panties': 3,
#          'Baggy': 1,
#          'Henley': 2,
#          'Flutter': 3,
#          'Embroidered': 6,
#          'Kaftan': 1,
#          'Arch': 4,
#          'White/Black': 1,
#          'Frida': 2,
#          'Postpartum': 1,
#          'Abdominal': 1,
#          'Binder': 1,
#          'Cactus': 1,
#          'Mustard': 1,
#          'Yellowstone': 2,
#          'Chili': 1,
#          'White/Black/Heather': 1,
#          'Double': 6,
#          'Black/Navy/Gray': 1,
#          'Twist': 3,
#          'U-Neck': 3,
#          'Cross': 3,
#          'Finish': 2,
#          'Line': 2,
#          'Miller': 1,
#          'Lite': 1,
#          'Geo': 3,
#          'Ultralight': 1,
#          'High-Cut': 1,
#          'Bold': 1,
#          'Asymmetrical': 1,
#          'Camisole': 1,
#          'Multi': 6,
#          'Bellaband': 1,
#          'Belt': 1,
#          'Anywhere': 1,
#          'Grommet': 1,
#          'Scallop': 1,
#          'Water': 1,
#          'Wear': 1,
#          'Push-Up': 3,
#          'Pads': 1,
#          "'Bold,": 1,
#          "Bougie'": 1,
#          'Dalmation': 1,
#          'Gold': 3,
#          'Invisible': 1,
#          'Bandeau': 5,
#          'Bishop': 4,
#          'Stud': 1,
#          'Backseam': 1,
#          'Cute': 1,
#          'Pups': 1,
#          'Vintage': 2,
#          'Jean': 3,
#          'Empowered': 1,
#          'Women': 2,
#          'Empower': 1,
#          'Pure': 2,
#          'Organic': 2,
#          'PP43WB': 1,
#          'Stranger': 1,
#          'Things': 1,
#          '120D': 1,
#          'Ivory/Black': 1,
#          'Net': 1,
#          'Crossback': 1,
#          'Beyondsoft': 2,
#          'L': 1,
#          'PP41AS': 1,
#          'Polo': 2,
#          'Heart': 2,
#          'Recycled': 1,
#          'XXL': 1,
#          "'Be": 1,
#          "Bright'": 1,
#          'Happy': 1,
#          'Mind': 1,
#          'Leather': 3,
#          'Red/White': 1,
#          'Jeggings': 1,
#          'Herringbone': 1,
#          "N'": 1,
#          'Keep': 1,
#          'Everyday': 2,
#          'Demi': 3,
#          'Jewel': 1,
#          'Cush': 2,
#          'Nickelodeon': 1,
#          'Rugrats': 1,
#          'Gown': 1,
#          'Flared': 1,
#          '-Colors': 2,
#          'Seamfree®': 1,
#          'Pique': 3,
#          'Varsity': 1,
#          'Blue/Pink': 1,
#          'Necklace': 1,
#          'Barnyard': 1,
#          'Animals': 1,
#          'Gray/Black/White': 1,
#          'Colorblock': 2,
#          'Diamond': 2,
#          'White/Black/Gray': 1,
#          'Outline': 1,
#          'Anklet': 3,
#          'Blue/Purple/Gray': 1,
#          'Future': 2,
#          'Collective': 2,
#          'Gabriella': 2,
#          'Karefa-Johnson': 2,
#          'Chevron': 1,
#          'NBA': 3,
#          'Warriors': 1,
#          'Whitney': 1,
#          'Houston': 1,
#          'Hope': 1,
#          'Henry': 1,
#          "Womens'": 1,
#          'Embossed': 1,
#          'Protect': 1,
#          'Your': 1,
#          'Peace': 1,
#          'Women’s': 1,
#          "Valentine's": 1,
#          '100': 1,
#          'Clubhouse': 1,
#          'Smoothing': 4,
#          'Boyz': 1,
#          'N': 1,
#          'Hood': 1,
#          '11"': 1,
#          'Drawstring': 2,
#          'Vibes': 2,
#          'Shimmer': 1,
#          'Garter': 1,
#          'L-Band': 1,
#          'Sole': 1,
#          'Daydream': 1,
#          'Powersox': 1,
#          'Shawl': 1,
#          'Lavender': 1,
#          'Pom': 1,
#          'Poms': 1,
#          'Checkered': 1,
#          'Cherry': 1,
#          'Cinch-Front': 1,
#          'Zion': 1,
#          'Grogu': 1,
#          'Stronger': 1,
#          'Than': 1,
#          'You': 1,
#          'Think': 1,
#          'Paisley': 2,
#          'Flounce': 2,
#          'Neckline': 1,
#          'Dutton': 1,
#          'Ranch': 1,
#          'Forming': 1,
#          'White/Gray/Black': 2,
#          'Ruffled': 1,
#          'Forms®': 1,
#          'Lift': 1,
#          'Backless/Strapless': 1,
#          'TLC': 1,
#          'Serene': 1,
#          'Ivory/Heather': 2,
#          'Gray/Blue': 1,
#          "'Hoppy": 1,
#          "Paddy's": 1,
#          "Day'": 1,
#          'Openwork': 1,
#          'Sparkle': 1,
#          'Sand': 1,
#          'Essentials': 1,
#          'Cuddl': 1,
#          'Duds': 1,
#          'DENIZEN®': 2,
#          'from': 2,
#          "Levi's®": 2,
#          'Enough': 1,
#          'Plants': 1,
#          'Bootcut': 1,
#          'Padded': 1,
#          'Cream/Gray': 1,
#          'Contemporary': 1,
#          'Heather/Ivory': 1,
#          'Velour': 2,
#          'White/Light': 1,
#          'Gray/Dark': 1,
#          'Cheetah': 1,
#          'Cutoff': 1,
#          'Fluffy': 1,
#          'Moto': 1,
#          '80D': 1,
#          'Heel/Toe': 1,
#          ...})

# %%
data = cloth_word_count.most_common()

# %%
data
# Out:
# [('-', 1121),
#  ('Socks', 304),
#  ('4-10', 221),
#  ('Day', 186),
#  ("Women's", 181),
#  ('Sleeve', 167),
#  ('Wild', 157),
#  ('Fable', 157),
#  ('A', 157),
#  ('New', 156),
#  ('6pk', 130),
#  ('Top', 124),
#  ('Bikini', 124),
#  ('All', 122),
#  ('Short', 112),
#  ('Cut', 108),
#  ('T-Shirt', 107),
#  ('in', 102),
#  ('Black', 101),
#  ('Motion', 100),
#  ('Low', 96),
#  ('Auden', 92),
#  ('Xhilaration', 84),
#  ('Universal', 77),
#  ('Thread', 77),
#  ('&', 77),
#  ('Athletic', 71),
#  ('Hanes', 67),
#  ('Graphic', 66),
#  ('High', 64),
#  ('No', 64),
#  ('Show', 63),
#  ('High-Rise', 61),
#  ('Liner', 60),
#  ('Colors', 59),
#  ('Pants', 57),
#  ('Bottom', 55),
#  ('Seamless', 53),
#  ('Ribbed', 51),
#  ('Tank', 50),
#  ('Cotton', 50),
#  ('Shorts', 49),
#  ('Dress', 49),
#  ('Cushioned', 49),
#  ('3pk', 49),
#  ('Stars', 48),
#  ('Above', 48),
#  ('Crew', 47),
#  ('Kona', 46),
#  ('Sol', 46),
#  ('Ankle', 45),
#  ('Fit', 44),
#  ('Cheeky', 44),
#  ('Underwear', 44),
#  ('Long', 43),
#  ('Bra', 42),
#  ('Sweatshirt', 42),
#  ('Bralette', 39),
#  ('Print', 39),
#  ('Leggings', 38),
#  ('Soft', 37),
#  ('Premium', 37),
#  ('Blue', 35),
#  ('Assorted', 35),
#  ('May', 35),
#  ('Vary', 35),
#  ('One', 34),
#  ('Gray', 34),
#  ('Cozy', 34),
#  ('Rose', 34),
#  ('Size', 33),
#  ('Leg', 32),
#  ('Shade', 31),
#  ('Shore', 31),
#  ('Knox', 31),
#  ('by', 30),
#  ('Lightweight', 30),
#  ('2pk', 30),
#  ('Colsie', 30),
#  ('Floral', 30),
#  ('Jeans', 30),
#  ('Maternity', 30),
#  ('Isabel', 30),
#  ('Slim', 29),
#  ('V-Neck', 29),
#  ('the', 29),
#  ('4pk', 29),
#  ('White', 28),
#  ('Striped', 28),
#  ('Tights', 28),
#  ('with', 27),
#  ('Waist', 27),
#  ('of', 27),
#  ('10pk', 27),
#  ('Cropped', 26),
#  ('Peds', 26),
#  ('Fruit', 26),
#  ('St.', 25),
#  ('Pajama', 25),
#  ('Swimsuit', 25),
#  ("Patrick's", 24),
#  ('Hipster', 24),
#  ('Light', 24),
#  ('Briefs', 24),
#  ('Piece', 24),
#  ('Green', 23),
#  ('Extended', 23),
#  ('Neck', 23),
#  ('Lace', 23),
#  ('Mesh', 23),
#  ('Loom', 23),
#  ('Heather', 22),
#  ('Ultra', 22),
#  ('Beautifully', 21),
#  ('8-12', 21),
#  ('Support', 21),
#  ('Up', 20),
#  ('5-9', 20),
#  ('and', 20),
#  ('Front', 19),
#  ('5-10', 19),
#  ('Coverage', 19),
#  ('Fleece', 18),
#  ('Cover', 18),
#  ('Mid-Rise', 18),
#  ('Triangle', 18),
#  ('Aqua', 18),
#  ('Tab', 18),
#  ('Lounge', 17),
#  ('Sweater', 17),
#  ('Straight', 17),
#  ('Medium', 17),
#  ('Satin', 17),
#  ('Active', 16),
#  ('Sleeveless', 16),
#  ('Sports', 16),
#  ('Sheer', 16),
#  ('Pro', 16),
#  ('Flare', 15),
#  ('Comfort', 15),
#  ('Ingrid', 15),
#  ('Scoop', 15),
#  ('Thong', 14),
#  ('Skirt', 14),
#  ('Cami', 13),
#  ('Oversized', 13),
#  ('Knit', 13),
#  ('Wash', 13),
#  ('Ava', 13),
#  ('Viv', 13),
#  ('Control', 13),
#  ('Textured', 13),
#  ('High-Waisted', 12),
#  ('Shoulder', 12),
#  ('Pull-On', 12),
#  ('Side', 12),
#  ('Jogger', 12),
#  ('Pullover', 12),
#  ('Puff', 12),
#  ('Super-High', 12),
#  ('Rise', 12),
#  ('Ruffle', 12),
#  ('Performance', 12),
#  ('Shamrock', 11),
#  ('Shirt', 11),
#  ('Relaxed', 11),
#  ('Square', 11),
#  ('Pink', 11),
#  ('Out', 11),
#  ('Orange', 11),
#  ('Set', 11),
#  ('Bodysuit', 11),
#  ('Longline', 11),
#  ('Skinny', 11),
#  ('The', 11),
#  ('French', 11),
#  ('Terry', 11),
#  ('Side-Tie', 11),
#  ('Pack', 10),
#  ('Wide', 10),
#  ('Brushed', 10),
#  ('Sculpt', 10),
#  ('Ruched', 10),
#  ('Cool', 10),
#  ('Racerback', 10),
#  ('Tankini', 10),
#  ('Button-Down', 9),
#  ('Fashion', 9),
#  ('Stretch', 9),
#  ('Full', 9),
#  ('Knee', 9),
#  ('A-Line', 9),
#  ('Charcoal', 9),
#  ('Flex', 9),
#  ('Notch', 9),
#  ('Collar', 9),
#  ('Shirred', 9),
#  ('Perfect', 9),
#  ('Sport', 9),
#  ('Swim', 9),
#  ('Plunge', 9),
#  ('Green®', 9),
#  ('Lace-Up', 9),
#  ('Jockey', 9),
#  ('Generation', 9),
#  ('Sleep', 8),
#  ('Forms', 8),
#  ('Smocked', 8),
#  ('6', 8),
#  ('Linen', 8),
#  ('Nursing', 8),
#  ('Rib', 8),
#  ('Denim', 8),
#  ('Over', 8),
#  ('ASSETS', 8),
#  ('SPANX', 8),
#  ('Brown', 8),
#  ('Jacket', 8),
#  ('Blouse', 8),
#  ('Opaque', 8),
#  ('Tie-Front', 8),
#  ('Super', 8),
#  ('Back', 8),
#  ('Crochet', 8),
#  ('3/4', 8),
#  ('Crewneck', 8),
#  ('Boxy', 7),
#  ('Laser', 7),
#  ('Woven', 7),
#  ('Micro', 7),
#  ('Robe', 7),
#  ('Cat', 7),
#  ('Slipper', 7),
#  ('Waistband', 7),
#  ('Strap', 7),
#  ('Navy', 7),
#  ('Thigh', 7),
#  ('Essential', 7),
#  ('Beige', 7),
#  ('Contour', 7),
#  ('Power', 7),
#  ('Tiered', 7),
#  ('Plus', 7),
#  ('Bike', 7),
#  ('20D', 7),
#  ('Stitch', 7),
#  ('Tropical', 7),
#  ('Purple', 7),
#  ('Breathable', 7),
#  ('Classic', 6),
#  ('Dark', 6),
#  ('Casual', 6),
#  ('Perfectly', 6),
#  ('Strapless', 6),
#  ('Fitted', 6),
#  ('Faux', 6),
#  ('Cardigan', 6),
#  ('Cream', 6),
#  ('JoyLab', 6),
#  ('Highs', 6),
#  ('Cushion', 6),
#  ('Heel', 6),
#  ('NightGown', 6),
#  ('Tie-Dye', 6),
#  ('Animal', 6),
#  ('History', 6),
#  ('Month', 6),
#  ('Adjustable', 6),
#  ('Eyelet', 6),
#  ('Detail', 6),
#  ('Accents', 6),
#  ('Extra', 6),
#  ('Pucker', 6),
#  ('Embroidered', 6),
#  ('Double', 6),
#  ('Multi', 6),
#  ('Elbow', 5),
#  ('Tapered', 5),
#  ('Rainbow', 5),
#  ('Oatmeal', 5),
#  ('Bonded', 5),
#  ('Marled', 5),
#  ('Midi', 5),
#  ('Trim', 5),
#  ('Boy', 5),
#  ('Sloth', 5),
#  ('Adhesive', 5),
#  ('Peach', 5),
#  ('Gauze', 5),
#  ('Distressed', 5),
#  ('Utility', 5),
#  ('High-Waist', 5),
#  ('Nude', 5),
#  ('Corset', 5),
#  ('Pantyhose', 5),
#  ('Simply', 5),
#  ('Boyfriend', 5),
#  ('Fishnet', 5),
#  ('Balloon', 5),
#  ('Ivory', 5),
#  ('Waisted', 5),
#  ('Grippers', 5),
#  ('Strappy', 5),
#  ('Hi-Cut', 5),
#  ('Underwire', 5),
#  ('Toe', 5),
#  ('Bandeau', 5),
#  ('Pockets', 4),
#  ('Reusable', 4),
#  ('Petals', 4),
#  ('Multipattern', 4),
#  ('Lucky', 4),
#  ('Llama', 4),
#  ('Slit', 4),
#  ('Taper', 4),
#  ('Bodycon', 4),
#  ('Cow', 4),
#  ('Backless', 4),
#  ('Risque', 4),
#  ('Nipple', 4),
#  ('Covers,', 4),
#  ('Maxi', 4),
#  ('Baby', 4),
#  ('Midline', 4),
#  ('Panda', 4),
#  ('Low-Rise', 4),
#  ('Rolling', 4),
#  ('Stones', 4),
#  ('Brami', 4),
#  ('Hoodie', 4),
#  ('Boxer', 4),
#  ('Wrap', 4),
#  ('Tummy', 4),
#  ('Black/White', 4),
#  ('Minnie', 4),
#  ('Simplicity', 4),
#  ('Coffee', 4),
#  ('Star', 4),
#  ('Microfiber', 4),
#  ('50D', 4),
#  ('FX', 4),
#  ('Lilo', 4),
#  ('So', 4),
#  ('Unlined', 4),
#  ('Fine', 4),
#  ('Lightly', 4),
#  ('Lined', 4),
#  ('Wirefree', 4),
#  ('briefs', 4),
#  ('Crossover', 4),
#  ('Disney', 4),
#  ('Mom', 4),
#  ('Halter', 4),
#  ('Tie', 4),
#  ('Tunic', 4),
#  ('Mouse', 4),
#  ('Arch', 4),
#  ('Bishop', 4),
#  ('Smoothing', 4),
#  ('Shamrocks', 3),
#  ('Alexander', 3),
#  ('Rossa', 3),
#  ('Pig', 3),
#  ('Cargo', 3),
#  ('Fuzzy', 3),
#  ('Shirtdress', 3),
#  ('Pointelle', 3),
#  ('Navy/Green', 3),
#  ('Short-Sleeve', 3),
#  ('Shrunken', 3),
#  ('Black/White/Gray', 3),
#  ('Reversible', 3),
#  ('String', 3),
#  ('Open', 3),
#  ('Shaping', 3),
#  ('Blazer', 3),
#  ('Jumpsuit', 3),
#  ('Waffle', 3),
#  ('Skater', 3),
#  ('Ombre', 3),
#  ('Mixed', 3),
#  ('Pattern', 3),
#  ('Stripe', 3),
#  ('It', 3),
#  ('Plisse', 3),
#  ('Babydoll', 3),
#  ('White/Green', 3),
#  ('My', 3),
#  ('Black,', 3),
#  ('Hanes®', 3),
#  ('Hooded', 3),
#  ('Farm', 3),
#  ('Core', 3),
#  ('Logo', 3),
#  ('Mini', 3),
#  ('Kick', 3),
#  ('Critters', 3),
#  ('Cats', 3),
#  ('Bears', 3),
#  ('Harry', 3),
#  ('Potter', 3),
#  ('Curvy', 3),
#  ('Sarong', 3),
#  ('Mandalorian', 3),
#  ('Yellow', 3),
#  ('Red', 3),
#  ('100%', 3),
#  ('Belly', 3),
#  ('Button-Front', 3),
#  ('Ring', 3),
#  ('Gauge', 3),
#  ('Ponte', 3),
#  ('Micro-Mesh', 3),
#  ('Retro', 3),
#  ('Sailor', 3),
#  ('Moon', 3),
#  ('Crop', 3),
#  ('Thermal', 3),
#  ('Twist-Front', 3),
#  ('Panties', 3),
#  ('Flutter', 3),
#  ('Twist', 3),
#  ('U-Neck', 3),
#  ('Cross', 3),
#  ('Geo', 3),
#  ('Push-Up', 3),
#  ('Gold', 3),
#  ('Jean', 3),
#  ('Leather', 3),
#  ('Demi', 3),
#  ('Pique', 3),
#  ('Anklet', 3),
#  ('NBA', 3),
#  ('Tiny', 2),
#  ('Plush', 2),
#  ('Bathrobe', 2),
#  ('del', 2),
#  ('Raglan', 2),
#  ('Nightshirt,', 2),
#  ('Nightgown', 2),
#  ('Gel', 2),
#  ('Irish', 2),
#  ('Warm', 2),
#  ('Sparkly', 2),
#  ('Muscle', 2),
#  ('Slip', 2),
#  ('Rainy', 2),
#  ('Disposable', 2),
#  ('40petals', 2),
#  ('Duster', 2),
#  ('Camping', 2),
#  ('Spaghetti', 2),
#  ('Dino', 2),
#  ('Unseen', 2),
#  ('Cable', 2),
#  ('Pull', 2),
#  ('Spring', 2),
#  ('Seamed', 2),
#  ('Bee', 2),
#  ('Bell', 2),
#  ('Black/Green', 2),
#  ('Periwinkle', 2),
#  ('Kind', 2),
#  ('Chiffon', 2),
#  ('Dog', 2),
#  ('Polka', 2),
#  ('Mary', 2),
#  ('Jane', 2),
#  ('Fold', 2),
#  ('Cuff', 2),
#  ('Layering', 2),
#  ('Zip-Up', 2),
#  ('3"', 2),
#  ('3.5"', 2),
#  ('Basic', 2),
#  ('Sanrio', 2),
#  ('Run', 2),
#  ('Blue/Gray/Pink', 2),
#  ('5"', 2),
#  ('Dot', 2),
#  ('Hamster', 2),
#  ('Corgi', 2),
#  ('Blue/White/Gray', 2),
#  ('Convertible', 2),
#  ('Spotted', 2),
#  ('Boyshorts', 2),
#  ('Fluid', 2),
#  ('Sublime', 2),
#  ('Slub', 2),
#  ('90s', 2),
#  ('Icons', 2),
#  ('White/Heather', 2),
#  ('Hem', 2),
#  ('7/8', 2),
#  ('Legging', 2),
#  ('Wars:', 2),
#  ('Microsuede', 2),
#  ('Stickies', 2),
#  ('2Cover(s)', 2),
#  ('Breakfast', 2),
#  ('Colorful', 2),
#  ('Coolmax', 2),
#  ('Mid-Thigh', 2),
#  ('Hedgehog', 2),
#  ('Guns', 2),
#  ('Roses', 2),
#  ('Drape', 2),
#  ('Leopard', 2),
#  ('Nylon', 2),
#  ('Abstract', 2),
#  ('Avocado', 2),
#  ('Easter', 2),
#  ('Bunny', 2),
#  ('Ears', 2),
#  ('Spritz', 2),
#  ('Bow', 2),
#  ('Corded', 2),
#  ('True', 2),
#  ('Wars', 2),
#  ('Gray/Pink', 2),
#  ('Blue/Pink/Gray', 2),
#  ('5pk', 2),
#  ('Modal', 2),
#  ('Blackout', 2),
#  ('Color', 2),
#  ('Side-Tab', 2),
#  ('Beauty', 2),
#  ('Tan', 2),
#  ('Skirtini', 2),
#  ('Butterfly', 2),
#  ('Mickey', 2),
#  ('Destructed', 2),
#  ('Spacedye', 2),
#  ('Romper', 2),
#  ('Gray/White', 2),
#  ('Nightmare', 2),
#  ('Before', 2),
#  ('Christmas', 2),
#  ('Care', 2),
#  ('Seamfree', 2),
#  ('Patterns', 2),
#  ('Zip', 2),
#  ('Henley', 2),
#  ('Frida', 2),
#  ('Yellowstone', 2),
#  ('Finish', 2),
#  ('Line', 2),
#  ('Vintage', 2),
#  ('Women', 2),
#  ('Pure', 2),
#  ('Organic', 2),
#  ('Beyondsoft', 2),
#  ('Polo', 2),
#  ('Heart', 2),
#  ('Everyday', 2),
#  ('Cush', 2),
#  ('-Colors', 2),
#  ('Colorblock', 2),
#  ('Diamond', 2),
#  ('Future', 2),
#  ('Collective', 2),
#  ('Gabriella', 2),
#  ('Karefa-Johnson', 2),
#  ('Drawstring', 2),
#  ('Vibes', 2),
#  ('Paisley', 2),
#  ('Flounce', 2),
#  ('White/Gray/Black', 2),
#  ('Ivory/Heather', 2),
#  ('DENIZEN®', 2),
#  ('from', 2),
#  ("Levi's®", 2),
#  ('Velour', 2),
#  ('Maidenform', 2),
#  ('Self', 2),
#  ('Expressions', 2),
#  ("Warner's", 2),
#  ('Comfortable', 2),
#  ('Off-White', 2),
#  ('Gingham', 2),
#  ('Slimming', 2),
#  ('Proof', 2),
#  ('Absorbency', 2),
#  ('90', 1),
#  ('Degree', 1),
#  ('Reflex', 1),
#  ('Comfy', 1),
#  ('Tonal', 1),
#  ('Unisex', 1),
#  ('Adult', 1),
#  ('Nile', 1),
#  ('Mills', 1),
#  ('Gradient', 1),
#  ('Pockets,', 1),
#  ('Shirt,', 1),
#  ('Collared', 1),
#  ('Silicone', 1),
#  ('Tape', 1),
#  ('With', 1),
#  ('Dispenser', 1),
#  ('Doxie', 1),
#  ('Pug', 1),
#  ('Guinea', 1),
#  ('Del', 1),
#  ('Winter', 1),
#  ('Robe,', 1),
#  ('Length', 1),
#  ("'Top", 1),
#  ('Meowning', 1),
#  ('to', 1),
#  ("Ya'", 1),
#  ('Clouds', 1),
#  ('Allover', 1),
#  ('Button-Up', 1),
#  ('Chenille', 1),
#  ("'Feelin'", 1),
#  ("Clucky'", 1),
#  ('Pizza', 1),
#  ('Solid', 1),
#  ('Slouch', 1),
#  ('Placket', 1),
#  ('Farmer', 1),
#  ('Chicken', 1),
#  ('Figure', 1),
#  ('Clear', 1),
#  ('Faces', 1),
#  ('Hamburger', 1),
#  ('Fur', 1),
#  ('Dr.', 1),
#  ('Hearts', 1),
#  ('Heather/Green', 1),
#  ('Hedgehogs', 1),
#  ('Kindness', 1),
#  ('Strawberry', 1),
#  ('Shortcake', 1),
#  ('Lingerie', 1),
#  ('Tanga', 1),
#  ('Nirvana', 1),
#  ('Party', 1),
#  ('Open-Front', 1),
#  ('Snorkeling', 1),
#  ('Workout', 1),
#  ('Hamsters', 1),
#  ('Hello', 1),
#  ('Kitty', 1),
#  ('Snails', 1),
#  ('Original', 1),
#  ('House', 1),
#  ('Plant', 1),
#  ('Olive', 1),
#  ('Fly', 1),
#  ('Away', 1),
#  ('Fern', 1),
#  ('Matte', 1),
#  ('show', 1),
#  ('DJ', 1),
#  ('Be', 1),
#  ('Festival', 1),
#  ('Pandas', 1),
#  ('Pool', 1),
#  ('Floaty', 1),
#  ("'Easy", 1),
#  ("Beezy'", 1),
#  ('Zip-Front', 1),
#  ('Blue/Gray', 1),
#  ('"Drop', 1),
#  ('Like', 1),
#  ('Sloth"', 1),
#  ('Non-Adhesive', 1),
#  ('Multitasking', 1),
#  ('Octopus', 1),
#  ('"Meowning', 1),
#  ('Coffee"', 1),
#  ("'Stay", 1),
#  ("Golden'", 1),
#  ('Dots', 1),
#  ('Budweiser', 1),
#  ('Space', 1),
#  ('Dreaming', 1),
#  ('Llamas', 1),
#  ('Foldover', 1),
#  ('Leprechaun', 1),
#  ('Gnome', 1),
#  ('Pear', 1),
#  ('Sheep', 1),
#  ('Vacation', 1),
#  ('Bear', 1),
#  ('White/Black/Pink', 1),
#  ("Schitt's", 1),
#  ('Creek', 1),
#  ('Apothecary', 1),
#  ('8pk', 1),
#  ('Day&#153', 1),
#  ('Melody', 1),
#  ('Beautiful,', 1),
#  ('Proud', 1),
#  ('Off', 1),
#  ("'Incorgnito'", 1),
#  ('Dolphin', 1),
#  ('Silky', 1),
#  ('X-Side', 1),
#  ('Amazing', 1),
#  ('Colorpop', 1),
#  ('Music', 1),
#  ('City', 1),
#  ('Barn', 1),
#  ('Def', 1),
#  ('Leppard', 1),
#  ('Bold,', 1),
#  ('Bougie', 1),
#  ('Bronze', 1),
#  ("Patricks'", 1),
#  ('Tupac', 1),
#  ('Science', 1),
#  ('Sushi', 1),
#  ('Umbrellas', 1),
#  ('Large', 1),
#  ('Yarn', 1),
#  ('Gummy', 1),
#  ('Fall', 1),
#  ('Berries', 1),
#  ('Sweatpants', 1),
#  ('Capri', 1),
#  ('20"', 1),
#  ('Mock', 1),
#  ('Turtleneck', 1),
#  ('-Stars', 1),
#  ('Gray/Black', 1),
#  ('Lattes', 1),
#  ('Black/Cream/Pink', 1),
#  ('Breast', 1),
#  ('Handkerchief', 1),
#  ('Supplex', 1),
#  ('Frenchie', 1),
#  ('Fry', 1),
#  ('Polyester', 1),
#  ('Shelf', 1),
#  ('Looney', 1),
#  ('Tunes', 1),
#  ("That's", 1),
#  ('Folks', 1),
#  ('On', 1),
#  ('Boyshort', 1),
#  ('Child', 1),
#  ('7-9.5', 1),
#  ('Gilmore', 1),
#  ('Girls', 1),
#  ("Luke's", 1),
#  ('Simple', 1),
#  ('Wishes', 1),
#  ('Hands', 1),
#  ('Free', 1),
#  ('Pumping', 1),
#  ('XS-L', 1),
#  ('Outerspace', 1),
#  ('Gray/White/Black', 1),
#  ('Removable', 1),
#  ('Pad', 1),
#  ('Drapey', 1),
#  ('Wyoming', 1),
#  ('Daisy', 1),
#  ('Days', 1),
#  ('Week', 1),
#  ('Snacks', 1),
#  ('Two-Tone', 1),
#  ('V-Wire', 1),
#  ('St', 1),
#  ('Gudetama', 1),
#  ('Cream/Gray/Olive', 1),
#  ('Yoga', 1),
#  ('Voice,', 1),
#  ('3pc', 1),
#  ('Navy/Pink', 1),
#  ('Ballet', 1),
#  ('Comfortsoft', 1),
#  ('Shark', 1),
#  ('Sunglasses', 1),
#  ('White/Pink/Heather', 1),
#  ('Flintstones', 1),
#  ('Burgundy', 1),
#  ('Drinking', 1),
#  ('Tassle', 1),
#  ("n'", 1),
#  ('Exercise', 1),
#  ('Camaro', 1),
#  ('Dinosaur', 1),
#  ('Navy/White/Pink', 1),
#  ('Dinosaurs', 1),
#  ('Stripes', 1),
#  ('Pink/Blue/Purple', 1),
#  ('Yosemite', 1),
#  ('High-Neck', 1),
#  ('Boilersuit', 1),
#  ('Toast', 1),
#  ('Racer', 1),
#  ('Tube', 1),
#  ('Bliss', 1),
#  ('Co.', 1),
#  ('Everybody', 1),
#  ('Hair', 1),
#  ('Pic', 1),
#  ('Memory', 1),
#  ('Gray/Blue/Yellow', 1),
#  ('Airy', 1),
#  ('Pindot', 1),
#  ('Citrus', 1),
#  ('Fruits', 1),
#  ('MTV', 1),
#  ('Tactel', 1),
#  ('Mule', 1),
#  ('Gray/Pink/Blue', 1),
#  ('Liquid', 1),
#  ('Black/White/Heather', 1),
#  ('Rib-Knit', 1),
#  ('Winnie', 1),
#  ('Pooh', 1),
#  ('Side-Slit', 1),
#  ('Natural', 1),
#  ('Hi-Cuts', 1),
#  ('Signature', 1),
#  ('Smooth', 1),
#  ('Mario', 1),
#  ('Pixar', 1),
#  ('Tinkerbell', 1),
#  ('Forest', 1),
#  ('Sun', 1),
#  ('10-12', 1),
#  ('Joe', 1),
#  ('Snoopy', 1),
#  ('Bermuda', 1),
#  ('Elastic', 1),
#  ('Argyle', 1),
#  ('Blend', 1),
#  ('Merino', 1),
#  ('Wool', 1),
#  ('XL', 1),
#  ('Charm', 1),
#  ('Knot', 1),
#  ('Trucker', 1),
#  ('White/Red/Blue', 1),
#  ('Texas', 1),
#  ('+', 1),
#  ('Balconette', 1),
#  ('Traction', 1),
#  ('Sweetheart', 1),
#  ('Viney', 1),
#  ('Taco', 1),
#  ('Mint/Blue/White', 1),
#  ('Floyd', 1),
#  ('Pleated', 1),
#  ('Skorts', 1),
#  ('Loom®', 1),
#  ('Fx', 1),
#  ('White/Purple', 1),
#  ('4"', 1),
#  ('7"', 1),
#  ('Playful', 1),
#  ('Keyhole', 1),
#  ('Angled', 1),
#  ('Honey', 1),
#  ('Quarter', 1),
#  ('Watermelon', 1),
#  ('Puppy', 1),
#  ('Heather/Heather', 1),
#  ('Rosie', 1),
#  ('Houses', 1),
#  ('Baggy', 1),
#  ('Kaftan', 1),
#  ('White/Black', 1),
#  ('Postpartum', 1),
#  ('Abdominal', 1),
#  ('Binder', 1),
#  ('Cactus', 1),
#  ('Mustard', 1),
#  ('Chili', 1),
#  ('White/Black/Heather', 1),
#  ('Black/Navy/Gray', 1),
#  ('Miller', 1),
#  ('Lite', 1),
#  ('Ultralight', 1),
#  ('High-Cut', 1),
#  ('Bold', 1),
#  ('Asymmetrical', 1),
#  ('Camisole', 1),
#  ('Bellaband', 1),
#  ('Belt', 1),
#  ('Anywhere', 1),
#  ('Grommet', 1),
#  ('Scallop', 1),
#  ('Water', 1),
#  ('Wear', 1),
#  ('Pads', 1),
#  ("'Bold,", 1),
#  ("Bougie'", 1),
#  ('Dalmation', 1),
#  ('Invisible', 1),
#  ('Stud', 1),
#  ('Backseam', 1),
#  ('Cute', 1),
#  ('Pups', 1),
#  ('Empowered', 1),
#  ('Empower', 1),
#  ('PP43WB', 1),
#  ('Stranger', 1),
#  ('Things', 1),
#  ('120D', 1),
#  ('Ivory/Black', 1),
#  ('Net', 1),
#  ('Crossback', 1),
#  ('L', 1),
#  ('PP41AS', 1),
#  ('Recycled', 1),
#  ('XXL', 1),
#  ("'Be", 1),
#  ("Bright'", 1),
#  ('Happy', 1),
#  ('Mind', 1),
#  ('Red/White', 1),
#  ('Jeggings', 1),
#  ('Herringbone', 1),
#  ("N'", 1),
#  ('Keep', 1),
#  ('Jewel', 1),
#  ('Nickelodeon', 1),
#  ('Rugrats', 1),
#  ('Gown', 1),
#  ('Flared', 1),
#  ('Seamfree®', 1),
#  ('Varsity', 1),
#  ('Blue/Pink', 1),
#  ('Necklace', 1),
#  ('Barnyard', 1),
#  ('Animals', 1),
#  ('Gray/Black/White', 1),
#  ('White/Black/Gray', 1),
#  ('Outline', 1),
#  ('Blue/Purple/Gray', 1),
#  ('Chevron', 1),
#  ('Warriors', 1),
#  ('Whitney', 1),
#  ('Houston', 1),
#  ('Hope', 1),
#  ('Henry', 1),
#  ("Womens'", 1),
#  ('Embossed', 1),
#  ('Protect', 1),
#  ('Your', 1),
#  ('Peace', 1),
#  ('Women’s', 1),
#  ("Valentine's", 1),
#  ('100', 1),
#  ('Clubhouse', 1),
#  ('Boyz', 1),
#  ('N', 1),
#  ('Hood', 1),
#  ('11"', 1),
#  ('Shimmer', 1),
#  ('Garter', 1),
#  ('L-Band', 1),
#  ('Sole', 1),
#  ('Daydream', 1),
#  ('Powersox', 1),
#  ('Shawl', 1),
#  ('Lavender', 1),
#  ('Pom', 1),
#  ('Poms', 1),
#  ('Checkered', 1),
#  ('Cherry', 1),
#  ('Cinch-Front', 1),
#  ('Zion', 1),
#  ('Grogu', 1),
#  ('Stronger', 1),
#  ('Than', 1),
#  ('You', 1),
#  ('Think', 1),
#  ('Neckline', 1),
#  ('Dutton', 1),
#  ('Ranch', 1),
#  ('Forming', 1),
#  ('Ruffled', 1),
#  ('Forms®', 1),
#  ('Lift', 1),
#  ('Backless/Strapless', 1),
#  ('TLC', 1),
#  ('Serene', 1),
#  ('Gray/Blue', 1),
#  ("'Hoppy", 1),
#  ("Paddy's", 1),
#  ("Day'", 1),
#  ('Openwork', 1),
#  ('Sparkle', 1),
#  ('Sand', 1),
#  ('Essentials', 1),
#  ('Cuddl', 1),
#  ('Duds', 1),
#  ('Enough', 1),
#  ('Plants', 1),
#  ('Bootcut', 1),
#  ('Padded', 1),
#  ('Cream/Gray', 1),
#  ...]

# %%
keyword_df = pd.DataFrame(data, columns = ["Keyword","Frequency"])

# %%
keyword_df
# Out:
#         Keyword  Frequency
# 0             -       1121
# 1         Socks        304
# 2          4-10        221
# 3           Day        186
# 4       Women's        181
# ...         ...        ...
# 1101  Multi-Way          1
# 1102      Check          1
# 1103     Dolman          1
# 1104    Texture          1
# 1105     Shades          1
#
# [1106 rows x 2 columns]

# %%
keyword_df.to_csv("Target_keywords.csv",index = False)
